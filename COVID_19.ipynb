# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.rcParams['font.size']=13

# %%
read1=pd.read_csv("country_wise_latest.csv")
read1
# Out:
#          Country_Region  Confirmed  Deaths  Recovered  Active  New_cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New_deaths  New_recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            10             18                3.50                  69.49
# 1             6             63                2.95                  56.25
# 2             8            749                4.16                  67.34
# 3             0              0                5.73                  88.53
# 4             1              0                4.32                  25.47
# ..          ...            ...                 ...                    ...
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                      5.04                35526            737
# 1                      5.25                 4171            709
# 2                      6.17                23691           4282
# 3                      6.48                  884             23
# 4                     16.94                  749            201
# ..                      ...                  ...            ...
# 182                    2.08                 8916           1705
# 183                   12.50                   10              0
# 184                   57.98                 1619             72
# 185                    4.97                 3326           1226
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO_Region
# 0                 2.07  Eastern Mediterranean
# 1                17.00                 Europe
# 2                18.07                 Africa
# 3                 2.60                 Europe
# 4                26.84                 Africa
# ..                 ...                    ...
# 182              19.12  Eastern Mediterranean
# 183               0.00                 Africa
# 184               4.45  Eastern Mediterranean
# 185              36.86                 Africa
# 186              57.85                 Africa
#
# [187 rows x 15 columns]

# %%
cnt=read1.Country_Region.head(20)
case=read1.New_cases.head(20)
death=read1.New_deaths.head(20)
rec=read1.New_recovered.head(20)

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
plt.plot(cnt,case)
plt.plot(cnt,death)
plt.plot(cnt,rec)
plt.grid()
plt.legend(['case','death','rec']);
plt.xlabel('Paper_Name')
plt.ylabel('CASTS');

# %%
read1.duplicated().sum()
# Out:
# 0

# %%
read1.shape
# Out:
# (187, 15)

# %%
read1.isnull().sum()
# Out:
# Country_Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New_cases                 0
# New_deaths                0
# New_recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO_Region                0
# dtype: int64

# %%
read1.WHO_Region.value_counts()
# Out:
# Europe                   56
# Africa                   48
# Americas                 35
# Eastern Mediterranean    22
# Western Pacific          16
# South-East_Asia          10
# Name: WHO_Region, dtype: int64

# %% [markdown]
# Here , provinc/state has numbers of null values , so we have to clean it.

# %%
read1.head()
# Out:
#   Country_Region  Confirmed  Deaths  Recovered  Active  New_cases  New_deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New_recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
#
#    1 week % increase             WHO_Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa

# %%
read1.columns
# Out:
# Index(['Country_Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New_cases', 'New_deaths', 'New_recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO_Region'],
#       dtype='object')

# %%
read1.tail()
# Out:
#          Country_Region  Confirmed  Deaths  Recovered  Active  New_cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New_deaths  New_recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 182                    2.08                 8916           1705
# 183                   12.50                   10              0
# 184                   57.98                 1619             72
# 185                    4.97                 3326           1226
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO_Region
# 182              19.12  Eastern Mediterranean
# 183               0.00                 Africa
# 184               4.45  Eastern Mediterranean
# 185              36.86                 Africa
# 186              57.85                 Africa

# %%
read1.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New_cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New_deaths  New_recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# std     120.037173    4197.719635            3.454302              26.287694
# min       0.000000       0.000000            0.000000               0.000000
# 25%       0.000000       0.000000            0.945000              48.770000
# 50%       1.000000      22.000000            2.150000              71.320000
# 75%       6.000000     221.000000            3.875000              86.885000
# max    1076.000000   33728.000000           28.560000             100.000000
#
#        Deaths / 100 Recovered  Confirmed last week  1 week change  \
# count                  187.00         1.870000e+02     187.000000
# mean                      inf         7.868248e+04    9448.459893
# std                       NaN         3.382737e+05   47491.127684
# min                      0.00         1.000000e+01     -47.000000
# 25%                      1.45         1.051500e+03      49.000000
# 50%                      3.62         5.020000e+03     432.000000
# 75%                      6.44         3.708050e+04    3172.000000
# max                       inf         3.834677e+06  455582.000000
#
#        1 week % increase
# count         187.000000
# mean           13.606203
# std            24.509838
# min            -3.840000
# 25%             2.775000
# 50%             6.890000
# 75%            16.855000
# max           226.320000

# %%
new_var=['Country_Region','Deaths','Active','WHO_Region']
df=read1[new_var]

# %%
df
# Out:
#          Country_Region  Deaths  Active             WHO_Region
# 0           Afghanistan    1269    9796  Eastern Mediterranean
# 1               Albania     144    1991                 Europe
# 2               Algeria    1163    7973                 Africa
# 3               Andorra      52      52                 Europe
# 4                Angola      41     667                 Africa
# ..                  ...     ...     ...                    ...
# 182  West Bank and Gaza      78    6791  Eastern Mediterranean
# 183      Western Sahara       1       1                 Africa
# 184               Yemen     483     375  Eastern Mediterranean
# 185              Zambia     140    1597                 Africa
# 186            Zimbabwe      36    2126                 Africa
#
# [187 rows x 4 columns]

# %% [markdown]
# # Total Deaths In Different Regions Due To COVID-19

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=30)
sns.barplot(y='WHO_Region',x='Deaths',data=df,color='r')

# %%
Regions=read1.sort_values(by=['Deaths'],ascending=False).head(20)
Regions
# Out:
#      Country_Region  Confirmed  Deaths  Recovered   Active  New_cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
# 79            India    1480073   33408     951166   495499      44457
# 61           France     220352   30212      81212   108928       2551
# 157           Spain     272421   28432     150376    93613          0
# 132            Peru     389717   18418     272547    98752      13756
# 81             Iran     293606   15912     255144    22550       2434
# 138          Russia     816680   13334     602249   201097       5607
# 16          Belgium      66428    9822      17452    39154        402
# 35            Chile     347923    9187     319954    18782       2133
# 65          Germany     207112    9125     190314     7673        445
# 32           Canada     116458    8944          0   107514        682
# 37         Colombia     257101    8777     131161   117163      16306
# 154    South Africa     452529    7067     274925   170537       7096
# 120     Netherlands      53413    6160        189    47064        419
# 128        Pakistan     274289    5842     241026    27421       1176
# 161          Sweden      79395    5700          0    73695        398
#
#      New_deaths  New_recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 177           7              3               15.19                   0.48
# 111         342           8588               11.13                  76.82
# 85            5            147               14.26                  80.64
# 79          637          33598                2.26                  64.26
# 61           17            267               13.71                  36.86
# 157           0              0               10.44                  55.20
# 132         575           4697                4.73                  69.93
# 81          212           1931                5.42                  86.90
# 138          85           3077                1.63                  73.74
# 16            1             14               14.79                  26.27
# 35           75           1859                2.64                  91.96
# 65            1            259                4.41                  91.89
# 32           11              0                7.68                   0.00
# 37          508          11494                3.41                  51.02
# 154         298           9848                1.56                  60.75
# 120           1              0               11.53                   0.35
# 128          20           3592                2.13                  87.87
# 161           3              0                7.18                   0.00
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
# 23                     4.74              2118646         323729
# 177                 3190.26               296944           4764
# 111                   14.49               349396          46093
# 85                    17.68               244624           1662
# 79                     3.51              1155338         324735
# 61                    37.20               214023           6329
# 157                   18.91               264836           7585
# 132                    6.76               357681          32036
# 81                     6.24               276202          17404
# 138                    2.21               776212          40468
# 16                    56.28                64094           2334
# 35                     2.87               333029          14894
# 65                     4.79               203325           3787
# 32                      inf               112925           3533
# 37                     6.69               204005          53096
# 154                    2.57               373628          78901
# 120                 3259.26                52132           1281
# 128                    2.42               266096           8193
# 161                     inf                78048           1347
#
#      1 week % increase             WHO_Region
# 173              11.88               Americas
# 23               15.28               Americas
# 177               1.60                 Europe
# 111              13.19               Americas
# 85                0.68                 Europe
# 79               28.11        South-East_Asia
# 61                2.96                 Europe
# 157               2.86                 Europe
# 132               8.96               Americas
# 81                6.30  Eastern Mediterranean
# 138               5.21                 Europe
# 16                3.64                 Europe
# 35                4.47               Americas
# 65                1.86                 Europe
# 32                3.13               Americas
# 37               26.03               Americas
# 154              21.12                 Africa
# 120               2.46                 Europe
# 128               3.08  Eastern Mediterranean
# 161               1.73                 Europe

# %%
new_reg=Regions.WHO_Region
deaths=Regions.Deaths
active=Regions.Active
recover=Regions.Recovered

# %%
plt.figure(figsize=(15,7))
plt.plot(deaths,new_reg)
plt.plot(active,new_reg)
plt.plot(recover,new_reg)

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=60)
plt.grid()
sns.barplot(x='WHO_Region',y='Recovered',data=read1)

# %% [markdown]
# # Country-Region's Analysis for those who belongs to South-East Asia Region

# %%
east=read1[['Country_Region','Deaths','Active','Recovered']]
region=read1.WHO_Region=='South-East_Asia'

# %%
Asia=east[region]
Asia_df=Asia.sort_values(by=['Recovered'],ascending=False)
Asia_df
# Out:
#     Country_Region  Deaths  Active  Recovered
# 79           India   33408  495499     951166
# 13      Bangladesh    2965   97577     125683
# 80       Indonesia    4838   37292      58173
# 119          Nepal      48    4950      13754
# 167       Thailand      58     128       3111
# 106       Maldives      15     807       2547
# 158      Sri Lanka      11     673       2121
# 27           Burma       6      52        292
# 19          Bhutan       0      13         86
# 168    Timor-Leste       0      24          0

# %% [markdown]
# So , Our Great India has Maximum Numbers Of Recovered People in South-East Asia Region

# %%
from IPython.display import Image
Image(filename='india.jpg')

# %%
read1.Country_Region.value_counts()
# Out:
# Ukraine                             1
# Saint Vincent and the Grenadines    1
# Bahrain                             1
# Cuba                                1
# Lesotho                             1
#                                    ..
# Comoros                             1
# Algeria                             1
# Montenegro                          1
# Germany                             1
# Chad                                1
# Name: Country_Region, Length: 187, dtype: int64

# %% [markdown]
# # Total Deaths, Recovered,Active Cases in Brazil

# %%
basic=read1[['Country_Region','Deaths','Active','Recovered']]
reg=read1.Country_Region=='Brazil'

# %%
reg_df=basic[reg]
new_reg=reg_df.sort_values(by=['Deaths'])
new_reg
# Out:
#    Country_Region  Deaths  Active  Recovered
# 23         Brazil   87618  508116    1846641

# %% [markdown]
# # Country-Region's Analysis for those who belongs to Africa Region

# %%
fetch=read1.WHO_Region=='Africa'

# %%
fet_df=basic[fetch]
new_fetch=fet_df.sort_values(by=['Recovered'],ascending=False)
new_fetch
# Out:
#                Country_Region  Deaths  Active  Recovered
# 154              South Africa    7067  170537     274925
# 66                      Ghana     168    3655      29801
# 2                     Algeria    1163    7973      18837
# 124                   Nigeria     860   22117      18203
# 31                   Cameroon     391    2180      14539
# 42              Cote d'Ivoire      96    5198      10361
# 90                      Kenya     285    9857       7833
# 146                   Senegal     194    3093       6477
# 58                   Ethiopia     228    7933       6386
# 103                Madagascar      91    3339       6260
# 71                     Guinea      45     753       6257
# 40           Congo (Kinshasa)     208    2936       5700
# 62                      Gabon      49    2458       4682
# 109                Mauritania     156    1399       4653
# 185                    Zambia     140    1597       2815
# 107                      Mali     124     476       1913
# 104                    Malawi      99    1920       1645
# 29                 Cabo Verde      22     756       1550
# 33   Central African Republic      59    2994       1546
# 149              Sierra Leone      66     400       1317
# 156               South Sudan      46    1084       1175
# 18                      Benin      35     699       1036
# 123                     Niger      69      36       1027
# 57                   Eswatini      34    1257       1025
# 174                    Uganda       2     140        986
# 139                    Rwanda       5     899        975
# 26               Burkina Faso      53     121        926
# 54          Equatorial Guinea      51    2178        842
# 39        Congo (Brazzaville)      54    2317        829
# 34                       Chad      75      37        810
# 72              Guinea-Bissau      26    1125        803
# 144     Sao Tome and Principe      14     117        734
# 98                    Liberia      72     449        646
# 169                      Togo      18     249        607
# 186                  Zimbabwe      36    2126        542
# 110                 Mauritius      10       2        332
# 38                    Comoros       7      19        328
# 28                    Burundi       1      76        301
# 4                      Angola      41     667        242
# 55                    Eritrea       0      74        191
# 166                  Tanzania      21     305        183
# 97                    Lesotho      12     365        128
# 118                   Namibia       8    1734        101
# 63                     Gambia       8     252         66
# 22                   Botswana       2     674         63
# 148                Seychelles       0      75         39
# 183            Western Sahara       1       1          8
# 117                Mozambique      11    1690          0

# %%
plt.rcParams['figure.figsize'] = (15, 7)
plt.xticks(rotation=60)
plt.title("New Cases in WHO Regions")
sns.scatterplot(x='WHO_Region',y='New_cases',hue='WHO_Region',data=read1)

# %% [markdown]
# # New_cases in South Americas Region

# %%
south=read1[['Country_Region','New_cases','New_deaths','New_recovered']]
south_basic=read1.WHO_Region=='Americas'

# %%
ame=south[south_basic]
ame_df=ame.sort_values(by=['New_cases'],ascending=False)
ame_df
# Out:
#                        Country_Region  New_cases  New_deaths  New_recovered
# 173                                US      56336        1076          27941
# 23                             Brazil      23284         614          33728
# 37                           Colombia      16306         508          11494
# 132                              Peru      13756         575           4697
# 111                            Mexico       4973         342           8588
# 6                           Argentina       4890         120           2057
# 35                              Chile       2133          75           1859
# 20                            Bolivia       1752          64            309
# 50                 Dominican Republic       1248          20           1601
# 129                            Panama       1146          28            955
# 32                             Canada        682          11              0
# 41                         Costa Rica        612          11             88
# 180                         Venezuela        525           4            213
# 51                            Ecuador        467          17              0
# 76                           Honduras        465          50            117
# 53                        El Salvador        405           8            130
# 70                          Guatemala        256          27            843
# 131                          Paraguay        104           2            111
# 160                          Suriname         44           1             35
# 11                            Bahamas         40           0              0
# 44                               Cuba         37           0              2
# 74                              Haiti         25           1              0
# 73                             Guyana         19           0              0
# 86                            Jamaica         11           0              0
# 178                           Uruguay         10           1              3
# 5                 Antigua and Barbuda          4           0              5
# 170               Trinidad and Tobago          1           0              0
# 142  Saint Vincent and the Grenadines          0           0              0
# 69                            Grenada          0           0              0
# 141                       Saint Lucia          0           0              0
# 140             Saint Kitts and Nevis          0           0              0
# 17                             Belize          0           0              0
# 122                         Nicaragua          0           0              0
# 49                           Dominica          0           0              0
# 14                           Barbados          0           0              0

# %% [markdown]
# Max Number Of new cases in : US

# %% [markdown]
# In Above Data , There Are 0 values in 142 & belows rows , i will clean it

# %%
ame_df.drop(ame_df[ame_df.New_cases<=0].index,inplace=True)

# %%
ame_df
# Out:
#           Country_Region  New_cases  New_deaths  New_recovered
# 173                   US      56336        1076          27941
# 23                Brazil      23284         614          33728
# 37              Colombia      16306         508          11494
# 132                 Peru      13756         575           4697
# 111               Mexico       4973         342           8588
# 6              Argentina       4890         120           2057
# 35                 Chile       2133          75           1859
# 20               Bolivia       1752          64            309
# 50    Dominican Republic       1248          20           1601
# 129               Panama       1146          28            955
# 32                Canada        682          11              0
# 41            Costa Rica        612          11             88
# 180            Venezuela        525           4            213
# 51               Ecuador        467          17              0
# 76              Honduras        465          50            117
# 53           El Salvador        405           8            130
# 70             Guatemala        256          27            843
# 131             Paraguay        104           2            111
# 160             Suriname         44           1             35
# 11               Bahamas         40           0              0
# 44                  Cuba         37           0              2
# 74                 Haiti         25           1              0
# 73                Guyana         19           0              0
# 86               Jamaica         11           0              0
# 178              Uruguay         10           1              3
# 5    Antigua and Barbuda          4           0              5
# 170  Trinidad and Tobago          1           0              0

# %%
plt.title("New-Cases in South America")
plt.ylabel("Country-Reg",size=16)
plt.xlabel('Number of New Cases',size=16)
plt.xticks(rotation=60)
plt.scatter(y='Country_Region',x='New_cases',data=ame_df)

# %%
# !pip install wordcloud --quiet
from wordcloud import WordCloud

# %%
comment_words = ' '
  
for val in read1.WHO_Region.values: 
    val = str(val) 
    tokens = val.split() 
        
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 1000, height = 1000, 
                background_color ='black', 
                min_font_size = 10).generate(comment_words) 
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x1F443FE2E20>
