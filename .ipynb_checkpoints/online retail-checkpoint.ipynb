# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.rcParams['font.size']=15
plt.rcParams['figure.figsize']=(15,7)

# %%
raw_data=pd.read_csv('Online Retail.csv')

# %%
raw_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
raw_data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
raw_data.drop(raw_data[raw_data.CustomerID.isnull()].index,inplace=True)
raw_data.drop(raw_data[raw_data.Description.isnull()].index,inplace=True)

# %%
raw_data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
raw_data.duplicated().sum()
# Out:
# 0

# %%
raw_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
raw_data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 536641, dtype: bool

# %%
raw_data.duplicated().sum()
# Out:
# 0

# %%
raw_data.loc[raw_data.duplicated(),:]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
raw_data.drop_duplicates(inplace=True)

# %%
raw_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
raw_data.Country.value_counts()
# Out:
# United Kingdom          490300
# Germany                   9480
# France                    8541
# EIRE                      8184
# Spain                     2528
# Netherlands               2371
# Belgium                   2069
# Switzerland               1994
# Portugal                  1510
# Australia                 1258
# Norway                    1086
# Italy                      803
# Channel Islands            757
# Finland                    695
# Cyprus                     611
# Sweden                     461
# Unspecified                442
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     294
# USA                        291
# Hong Kong                  284
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
unit_sort=raw_data.sort_values(by=['UnitPrice'],ascending=False).head(20)
unit_sort
# Out:
#        InvoiceNo  StockCode      Description  Quantity      InvoiceDate  \
# 222681   C556445          M           Manual        -1  6/10/2011 15:31
# 524602   C580605  AMAZONFEE       AMAZON FEE        -1  12/5/2011 11:36
# 43702    C540117  AMAZONFEE       AMAZON FEE        -1    1/5/2011 9:55
# 43703    C540118  AMAZONFEE       AMAZON FEE        -1    1/5/2011 9:57
# 15016    C537630  AMAZONFEE       AMAZON FEE        -1  12/7/2010 15:04
# 15017     537632  AMAZONFEE       AMAZON FEE         1  12/7/2010 15:08
# 16356    C537651  AMAZONFEE       AMAZON FEE        -1  12/7/2010 15:49
# 16232    C537644  AMAZONFEE       AMAZON FEE        -1  12/7/2010 15:34
# 524601   C580604  AMAZONFEE       AMAZON FEE        -1  12/5/2011 11:35
# 299982   A563185          B  Adjust bad debt         1  8/12/2011 14:50
# 446533   C574902  AMAZONFEE       AMAZON FEE        -1  11/7/2011 15:21
# 173382    551697       POST          POSTAGE         1   5/3/2011 13:46
# ...

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='Country',y='UnitPrice',data=unit_sort)

# %%
raw_data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  536641.000000  536641.000000  401604.000000
# mean        9.620029       4.632656   15281.160818
# std       219.130156      97.233118    1714.006089
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13939.000000
# 50%         3.000000       2.080000   15145.000000
# 75%        10.000000       4.130000   16784.000000
# max     80995.000000   38970.000000   18287.000000

# %%
np.median(raw_data['UnitPrice'])
# Out:
# 2.08

# %% [markdown]
# # Let's Start With Saudi Arabia Country

# %%
new=raw_data[['StockCode','Description','UnitPrice']]
new_df=raw_data.Country=='Saudi Arabia'

# %%
arabia=new[new_df]
arabia_df=arabia.sort_values(by=['UnitPrice'],ascending=False)
arabia_df
# Out:
#        StockCode                        Description  UnitPrice
# 100817     20781           GOLD EAR MUFF HEADPHONES       5.49
# 100811     22363               GLASS JAR MARMALADE        2.95
# 100812     22362       GLASS JAR PEACOCK BATH SALTS       2.95
# 100813     22361  GLASS JAR DAISY FRESH COTTON WOOL       2.95
# 108127     22361  GLASS JAR DAISY FRESH COTTON WOOL       2.95
# 100814     22553             PLASTERS IN TIN SKULLS       1.65
# 100815     22555          PLASTERS IN TIN STRONGMAN       1.65
# 100816     22556     PLASTERS IN TIN CIRCUS PARADE        1.65
# 100818     22969       HOMEMADE JAM SCENTED CANDLES       1.45
# 100810     22915      ASSORTED BOTTLE TOP  MAGNETS        0.42

# %%
plt.figure(figsize=(15,8))
sns.barplot(y='Description',x='UnitPrice',data=arabia_df,edgecolor='darkblue')

# %% [markdown]
# So, From Above Barplot , we can say that in Saudi Arabia , GOLD EAR MUFF HEADPHONES have Maximum Unitprice.

# %% [markdown]
# # About Singapore

# %%
sau_cnt=raw_data[['StockCode','Description','UnitPrice']]
cnt_df=raw_data.Country=='Singapore'

# %%
saudi=sau_cnt[cnt_df]
saudi_df=saudi.sort_values(by=['UnitPrice'],ascending=True).head(10)
saudi_df
# Out:
#        StockCode                       Description  UnitPrice
# 398339     22339      CHRISTMAS TREE PAINTED ZINC        0.19
# 398340     22336     DOVE DECORATION PAINTED ZINC        0.19
# 70761      22343    PARTY PIZZA DISH RED RETROSPOT       0.21
# 70762      22344    PARTY PIZZA DISH PINK POLKADOT       0.21
# 70763      22345    PARTY PIZZA DISH BLUE POLKADOT       0.21
# 70764      22346   PARTY PIZZA DISH GREEN POLKADOT       0.21
# 146047     21986  PACK OF 12 PINK POLKADOT TISSUES       0.29
# 267737     20984         12 PENCILS TALL TUBE POSY       0.29
# 267741    81950B     FLOWER BLUE CLOCK WITH SUCKER       0.29
# 70758      21519   GIN & TONIC DIET GREETING CARD        0.36

# %%
plt.xticks(rotation=90)
sns.barplot(y='Description',x='UnitPrice',data=saudi_df,palette='Blues_d',edgecolor='green')

# %% [markdown]
# # USA Country

# %%
usa_cnt=raw_data[['StockCode','Description','UnitPrice','Quantity']]
usa_df=raw_data.Country=='USA'

# %%
usa_num=usa_cnt[usa_df]
final_usa=usa_num.sort_values(by=['Quantity'],ascending=True).head(20)
final_usa
# Out:
#        StockCode                          Description  UnitPrice  Quantity
# 536922     23158          SET OF 5 LUCKY CAT MAGNETS        2.08       -36
# 394033     22492              MINI PAINT SET VINTAGE        0.65       -36
# 394044     22050          PINK PAISLEY ROSE GIFT WRAP       0.42       -25
# 394045     22048           BIRTHDAY BANQUET GIFT WRAP       0.42       -25
# 394059     21498                  RED RETROSPOT WRAP        0.42       -25
# 394070    16161P                   WRAP ENGLISH ROSE        0.42       -25
# 394027     22708                      WRAP DOLLY GIRL       0.42       -25
# 394058     21499                   BLUE POLKADOT WRAP       0.42       -25
# 394046     22046           TEA PARTY  WRAPPING PAPER        0.42       -25
# 394028     22706                       WRAP COWBOYS         0.42       -25
# 394013     22959               WRAP CHRISTMAS VILLAGE       0.42       -25
# ...

# %%
name=final_usa.Description
unit=final_usa.UnitPrice
quantity=final_usa.Quantity

# %%
plt.xticks(rotation=90)
plt.plot(name,unit,marker='o',color='purple',mfc='y',markersize=10)
plt.plot(name,quantity,marker='*',color='green',mfc='y',markersize=10)
plt.legend(['UnitPrice','Quantity'])

# %% [markdown]
# # About Brazil

# %%
new_cnt=raw_data[['StockCode','Description','UnitPrice','Quantity']]
new_cnt_df=raw_data.Country=='Brazil'

# %%
brazil=new_cnt[new_cnt_df]
brazil_df=brazil.sort_values(by=['Quantity'],ascending=True)
brazil_df
# Out:
#        StockCode                         Description  UnitPrice  Quantity
# 157328     23049           RECYCLED ACAPULCO MAT RED       8.25         2
# 157327     23051          RECYCLED ACAPULCO MAT BLUE       8.25         2
# 157326     23050         RECYCLED ACAPULCO MAT GREEN       8.25         2
# 157325     23053          RECYCLED ACAPULCO MAT PINK       8.25         2
# 157324     23054      RECYCLED ACAPULCO MAT LAVENDER       8.25         2
# 157329     23052     RECYCLED ACAPULCO MAT TURQUOISE       8.25         2
# 157309   15056BL             EDWARDIAN PARASOL BLACK       5.95         3
# 157310    15056P              EDWARDIAN PARASOL PINK       5.95         3
# 157311    15056N           EDWARDIAN PARASOL NATURAL       5.95         3
# 157312     20679               EDWARDIAN PARASOL RED       5.95         3
# 157318     23179          CLOCK MAGNET MUM'S KITCHEN       2.89         6
# 157322     21906             PHARMACIE FIRST AID TIN       6.75         6
# ...

# %%
name=brazil_df.Description
unit=brazil_df.UnitPrice
quantity=brazil_df.Quantity

# %%
plt.xticks(rotation=90)
plt.plot(name,unit,color='purple',linewidth=5,marker='o',markersize=10)
plt.plot(name,quantity,color='green',linewidth=5,marker='o',markersize=10)
plt.legend(['UnitPrice','Quantity'])

# %%
new_uk=raw_data[['StockCode','Description','UnitPrice','Quantity']]
new_uk_df=raw_data.Country=='United Kingdom'

# %%
uk=new_uk[new_uk_df]
uk_df=uk.sort_values(by=['UnitPrice'],ascending=True)
uk_df
# Out:
#         StockCode            Description  UnitPrice  Quantity
# 299983          B        Adjust bad debt  -11062.06         1
# 299984          B        Adjust bad debt  -11062.06         1
# 418127      72818                    NaN       0.00       -48
# 220844      21135  sold as set on dotcom       0.00      -304
# 220843     85123A                      ?       0.00      4000
# ...           ...                    ...        ...       ...
# 15016   AMAZONFEE             AMAZON FEE   13541.33        -1
# 43703   AMAZONFEE             AMAZON FEE   16453.71        -1
# 43702   AMAZONFEE             AMAZON FEE   16888.02        -1
# 524602  AMAZONFEE             AMAZON FEE   17836.46        -1
# 222681          M                 Manual   38970.00        -1
#
# [490300 rows x 4 columns]

# %%
my_df=uk_df.sort_values(by=['UnitPrice'],ascending=False).head(20)
my_df
# Out:
#         StockCode      Description  UnitPrice  Quantity
# 222681          M           Manual   38970.00        -1
# 524602  AMAZONFEE       AMAZON FEE   17836.46        -1
# 43702   AMAZONFEE       AMAZON FEE   16888.02        -1
# 43703   AMAZONFEE       AMAZON FEE   16453.71        -1
# 15016   AMAZONFEE       AMAZON FEE   13541.33        -1
# 15017   AMAZONFEE       AMAZON FEE   13541.33         1
# 16356   AMAZONFEE       AMAZON FEE   13541.33        -1
# 16232   AMAZONFEE       AMAZON FEE   13474.79        -1
# 524601  AMAZONFEE       AMAZON FEE   11586.50        -1
# 299982          B  Adjust bad debt   11062.06         1
# 446533  AMAZONFEE       AMAZON FEE    8286.22        -1
# 173382       POST          POSTAGE    8142.75         1
# 173277       POST          POSTAGE    8142.75        -1
# 342635  AMAZONFEE       AMAZON FEE    7427.97        -1
# 191386  AMAZONFEE       AMAZON FEE    7006.83        -1
# 173391          M           Manual    6930.00        -1
# ...

# %%
sns.scatterplot(x='Description',y='UnitPrice',data=my_df)

# %% [markdown]
# # About France

# %%
fr=raw_data[['StockCode','Description','UnitPrice','Quantity']]
fr_df=raw_data.Country=='France'

# %%
france=fr[fr_df]
france_df=france.sort_values(by=['UnitPrice'],ascending=True).head(10)
france_df.drop(436961,axis=0,inplace=True)

# %%
france_df.sort_values(by=['UnitPrice'],ascending=True)
# Out:
#        StockCode                      Description  UnitPrice  Quantity
# 235166     16218       CARTOON  PENCIL SHARPENERS       0.06       240
# 221620     16219     HOUSE SHAPE PENCIL SHARPENER       0.06        48
# 509527     16218       CARTOON  PENCIL SHARPENERS       0.06        80
# 478937     20668  DISCO BALL CHRISTMAS DECORATION       0.12        72
# 310329     21402                  RED  EGG  SPOON       0.12        24
# 439993     21403                  BLUE EGG  SPOON       0.12         3
# 312753     16048  TEATIME ROUND PENCIL SHARPENER        0.12        24
# 377822     16048  TEATIME ROUND PENCIL SHARPENER        0.12        24
# 439992     21402                  RED  EGG  SPOON       0.12         3

# %%
plt.xticks(rotation=80)
sns.barplot(x='Description',y='UnitPrice',data=france_df,palette='rocket')
