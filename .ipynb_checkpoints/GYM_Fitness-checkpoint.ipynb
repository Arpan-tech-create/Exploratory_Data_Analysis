# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set_style('darkgrid')
plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(13,7)

# %%
raw_data=pd.read_csv('CardioGoodFitness.csv')
raw_data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
raw_data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
raw_data.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
plt.pie(raw_data.Gender.value_counts(),labels=raw_data.Gender.value_counts().index,autopct='%1.1f%%')
plt.title('Gender')
plt.show()

# %%
male_cnt=raw_data.Gender[raw_data.MaritalStatus=='Single']
male_cnt.value_counts()
# Out:
# Male      43
# Female    30
# Name: Gender, dtype: int64

# %%
par_cnt=raw_data.Gender[raw_data.MaritalStatus=='Partnered']
par_cnt.value_counts()
# Out:
# Male      61
# Female    46
# Name: Gender, dtype: int64

# %%
raw_data.MaritalStatus.value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
sns.pairplot(raw_data,hue='MaritalStatus')

# %%
px.box(raw_data,x='MaritalStatus',y='Income',color='Gender')
# Out:
# <div>                            <div id="aa07abf1-509b-4b9e-a824-c7ad8c8904e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa07abf1-509b-4b9e-a824-c7ad8c8904e3")) {                    Plotly.newPlot(                        "aa07abf1-509b-4b9e-a824-c7ad8c8904e3",                        [{"alignmentgroup": "True", "hovertemplate": "Gender=Male<br>MaritalStatus=%{x}<br>Income=%{y}<extra></extra>", "legendgroup": "Male", "marker": {"color": "#636efa"}, "name": "Male", "notched": false, "offsetgroup": "Male", "orientation": "v", "showlegend": true, "type": "box", "x": ["Single", "Single", "Single", "Partnered", "Single", "Single", "Single", "Partnered", "Partnered", "Partnered", "Single", "Single", "Single", "Partnered", "Partnered", "Single", "Sing
# ...

# %%
plt.xlabel('Income')
plt.ylabel('Miles')
plt.scatter(x='Income',y='Miles',data=raw_data)
