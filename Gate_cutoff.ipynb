# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams['font.size'] = 13
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
raw_data=pd.read_csv('gate_cutoff123.csv')

# %%
raw_data
# Out:
#     Sr No                                    PaperName Paper Code    GEN  \
# 0       1                                Life Sciences         XL  31.70
# 1       2                            Civil Engineering         CE  32.90
# 2       3                       Electrical Engineering         EE  33.40
# 3       4  Computer Science and Information Technology         CS  28.50
# 4       5                       Mechanical Engineering         ME  34.00
# ..    ...                                          ...        ...    ...
# 88     89                       Electrical Engineering         EE  25.00
# 89     90    Electronics and Communication Engineering         EC  25.00
# 90     91  Computer Science and Information Technology         CS  25.00
# 91     92                  Instrumentation Engineering         IN  25.45
# 92     93        Production and Industrial Engineering         PI  26.82
#
#       OBC  SC/ST  Year
# 0   28.50  21.10  2020
# 1   29.60  21.90  2020
# ...

# %%
raw_data.drop(['Sr No'],axis=1,inplace=True)

# %%
raw_data
# Out:
#                                       PaperName Paper Code    GEN    OBC  \
# 0                                 Life Sciences         XL  31.70  28.50
# 1                             Civil Engineering         CE  32.90  29.60
# 2                        Electrical Engineering         EE  33.40  30.00
# 3   Computer Science and Information Technology         CS  28.50  25.60
# 4                        Mechanical Engineering         ME  34.00  30.60
# ..                                          ...        ...    ...    ...
# 88                       Electrical Engineering         EE  25.00  22.50
# 89    Electronics and Communication Engineering         EC  25.00  22.50
# 90  Computer Science and Information Technology         CS  25.00  22.50
# 91                  Instrumentation Engineering         IN  25.45  22.90
# 92        Production and Industrial Engineering         PI  26.82  24.14
#
#     SC/ST  Year
# 0   21.10  2020
# 1   21.90  2020
# 2   22.20  2020
# 3   19.00  2020
# ...

# %%
raw_data.isnull().sum()
# Out:
# PaperName     0
# Paper Code    0
# GEN           0
# OBC           0
# SC/ST         0
# Year          0
# dtype: int64

# %% [markdown]
# # For General Category

# %%
raw_paper=['PaperName','GEN','Paper Code']
paper_df=raw_data[raw_paper]

# %%
paper_df
# Out:
#                                       PaperName    GEN Paper Code
# 0                                 Life Sciences  31.70         XL
# 1                             Civil Engineering  32.90         CE
# 2                        Electrical Engineering  33.40         EE
# 3   Computer Science and Information Technology  28.50         CS
# 4                        Mechanical Engineering  34.00         ME
# ..                                          ...    ...        ...
# 88                       Electrical Engineering  25.00         EE
# 89    Electronics and Communication Engineering  25.00         EC
# 90  Computer Science and Information Technology  25.00         CS
# 91                  Instrumentation Engineering  25.45         IN
# 92        Production and Industrial Engineering  26.82         PI
#
# [93 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.title("General category", color='r',size=15)
plt.xticks(rotation=0)
plt.grid()
sns.barplot(y='PaperName',x='GEN',data=paper_df)

# %%
plt.figure(figsize=(15,8))
plt.title("General category", color='r',size=15)
sns.barplot(y='PaperName',x='GEN',data=paper_df.head(10))

# %%
plt.figure(figsize=(15,8))
plt.title("General category", color='r',size=15)
plt.xticks(rotation=0)
plt.grid()
plt.scatter(y='PaperName',x='GEN',data=paper_df.head(30))

# %% [markdown]
# # For OBC Category

# %%
obc_var=['PaperName','OBC']
OBC_df=raw_data[obc_var]

# %%
OBC_df
# Out:
#                                       PaperName    OBC
# 0                                 Life Sciences  28.50
# 1                             Civil Engineering  29.60
# 2                        Electrical Engineering  30.00
# 3   Computer Science and Information Technology  25.60
# 4                        Mechanical Engineering  30.60
# ..                                          ...    ...
# 88                       Electrical Engineering  22.50
# 89    Electronics and Communication Engineering  22.50
# 90  Computer Science and Information Technology  22.50
# 91                  Instrumentation Engineering  22.90
# 92        Production and Industrial Engineering  24.14
#
# [93 rows x 2 columns]

# %%
OBC_df.PaperName.value_counts()
# Out:
# Civil Engineering                              6
# Mechanical Engineering                         6
# Electrical Engineering                         6
# Production and Industrial Engineering          5
# Computer Science and Information Technology    5
# Biotechnology                                  4
# Chemical Engineering                           4
# Instrumentation Engineering                    4
# Electronics and Communication Engineering      4
# Ecology and Evolution                          3
# Mining Engineering                             3
# Metallurgical Engineering                      3
# Agricultural Engineering                       3
# Architecture and Planning                      3
# Textile Engineering and Fibre Science          3
# Petroleum Engineering                          3
# Chemistry                                      3
# Life Sciences                                  3
# Mathematics                                    3
# ...

# %%
plt.figure(figsize=(15,8))
plt.title("OBC Category", color='r',size=15)
plt.grid(color='r')
sns.barplot(y='PaperName',x='OBC',palette="Blues_d",data=OBC_df.head(10))

# %% [markdown]
# # For SC/ST Category

# %%
tc_var=['PaperName','SC/ST']
tc_df=raw_data[tc_var]

# %%
tc_df
# Out:
#                                       PaperName  SC/ST
# 0                                 Life Sciences  21.10
# 1                             Civil Engineering  21.90
# 2                        Electrical Engineering  22.20
# 3   Computer Science and Information Technology  19.00
# 4                        Mechanical Engineering  22.60
# ..                                          ...    ...
# 88                       Electrical Engineering  16.67
# 89    Electronics and Communication Engineering  16.67
# 90  Computer Science and Information Technology  16.67
# 91                  Instrumentation Engineering  16.96
# 92        Production and Industrial Engineering  17.88
#
# [93 rows x 2 columns]

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=70)
plt.grid(color='black')
sns.barplot(y='PaperName',x='SC/ST',data=tc_df.iloc[15:30])
