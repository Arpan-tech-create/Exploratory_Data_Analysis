# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams['font.size'] = 13
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
raw_data=pd.read_csv('gate_cutoff123.csv')

# %%
raw_data
# Out:
#     SrNo                                  PaperName Paper Code    GEN    OBC  \
# 0      1                              Life Sciences         XL  31.70  28.50
# 1      2                          Civil Engineering         CE  32.90  29.60
# 2      3                     Electrical Engineering         EE  33.40  30.00
# 3      4                                      CS_IT         CS  28.50  25.60
# 4      5                     Mechanical Engineering         ME  34.00  30.60
# ..   ...                                        ...        ...    ...    ...
# 88    89                     Electrical Engineering         EE  25.00  22.50
# 89    90  Electronics and Communication Engineering         EC  25.00  22.50
# 90    91                                      CS_IT         CS  25.00  22.50
# 91    92                Instrumentation Engineering         IN  25.45  22.90
# 92    93      Production and Industrial Engineering         PI  26.82  24.14
#
#     SC_ST  Year
# 0   21.10  2020
# 1   21.90  2020
# 2   22.20  2020
# 3   19.00  2020
# 4   22.60  2020
# ..    ...   ...
# 88  16.67  2015
# 89  16.67  2015
# 90  16.67  2015
# 91  16.96  2015
# 92  17.88  2015
#
# [93 rows x 7 columns]

# %%
raw_data.drop(['SrNo'],axis=1,inplace=True)

# %%
raw_data
# Out:
#                                     PaperName Paper Code    GEN    OBC  SC_ST  \
# 0                               Life Sciences         XL  31.70  28.50  21.10
# 1                           Civil Engineering         CE  32.90  29.60  21.90
# 2                      Electrical Engineering         EE  33.40  30.00  22.20
# 3                                       CS_IT         CS  28.50  25.60  19.00
# 4                      Mechanical Engineering         ME  34.00  30.60  22.60
# ..                                        ...        ...    ...    ...    ...
# 88                     Electrical Engineering         EE  25.00  22.50  16.67
# 89  Electronics and Communication Engineering         EC  25.00  22.50  16.67
# 90                                      CS_IT         CS  25.00  22.50  16.67
# 91                Instrumentation Engineering         IN  25.45  22.90  16.96
# 92      Production and Industrial Engineering         PI  26.82  24.14  17.88
#
#     Year
# 0   2020
# 1   2020
# 2   2020
# 3   2020
# 4   2020
# ..   ...
# 88  2015
# 89  2015
# 90  2015
# 91  2015
# 92  2015
#
# [93 rows x 6 columns]

# %%
raw_data.isnull().sum()
# Out:
# PaperName     0
# Paper Code    0
# GEN           0
# OBC           0
# SC_ST         0
# Year          0
# dtype: int64

# %%
raw_df=raw_data.sort_values(by=['Year'],ascending=False).head(20)

# %%
raw_df
# Out:
#                                     PaperName Paper Code   GEN   OBC  SC_ST  \
# 0                               Life Sciences         XL  31.7  28.5   21.1
# 13                   Agricultural Engineering         AG  26.3  23.6   17.5
# 1                           Civil Engineering         CE  32.9  29.6   21.9
# 23                     Biomedical Engineering         BM  25.0  22.5   16.6
# 22                                 Statistics         ST  25.0  22.5   16.6
# 21      Production and Industrial Engineering         PI  36.6  32.9   24.4
# 20                                    Physics         PH  37.2  33.4   24.8
# 19                  Metallurgical Engineering         MT  49.2  44.2   32.8
# 18                         Mining Engineering         MN  32.7  29.4   21.8
# 16                                    Geology         GG  38.4  34.5   25.6
# 15                      Ecology and Evolution         EY  42.2  37.9   28.1
# 14                  Architecture and Planning         AR  34.8  31.3   23.2
# 17                                Mathematics         MA  25.0  22.5   16.7
# 12                      Aerospace Engineering         AE  27.2  24.4   18.1
# 10                 Engineering Sciences Minor         XE  26.0  23.4   17.3
# 9                               Biotechnology         BT  30.7  27.6   20.4
# 8                                   Chemistry         CY  26.7  24.0   17.8
# 7                        Chemical Engineering         CH  35.7  32.1   23.8
# 6   Electronics and Communication Engineering         EC  28.8  25.9   19.2
# 5                       Petroleum Engineering         PE  39.8  35.8   26.5
#
#     Year
# 0   2020
# 13  2020
# 1   2020
# 23  2020
# 22  2020
# 21  2020
# 20  2020
# 19  2020
# 18  2020
# 16  2020
# 15  2020
# 14  2020
# 17  2020
# 12  2020
# 10  2020
# 9   2020
# 8   2020
# 7   2020
# 6   2020
# 5   2020

# %%
top_paper=raw_df.PaperName
obc=raw_df.OBC
gen=raw_df.GEN
sc_st=raw_df.SC_ST

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=80)
plt.plot(top_paper,obc)
plt.plot(top_paper,gen)
plt.plot(top_paper,sc_st)
plt.legend(['OBC','GEN','SC_ST']);
plt.grid()
plt.xlabel('Paper_Name')
plt.ylabel('CASTS');

# %% [markdown]
# # For General Category

# %%
raw_paper=['PaperName','GEN','Paper Code']
paper_df=raw_data[raw_paper]

# %%
paper_df
# Out:
#                                     PaperName    GEN Paper Code
# 0                               Life Sciences  31.70         XL
# 1                           Civil Engineering  32.90         CE
# 2                      Electrical Engineering  33.40         EE
# 3                                       CS_IT  28.50         CS
# 4                      Mechanical Engineering  34.00         ME
# ..                                        ...    ...        ...
# 88                     Electrical Engineering  25.00         EE
# 89  Electronics and Communication Engineering  25.00         EC
# 90                                      CS_IT  25.00         CS
# 91                Instrumentation Engineering  25.45         IN
# 92      Production and Industrial Engineering  26.82         PI
#
# [93 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.title("General category", color='r',size=15)
plt.xticks(rotation=0)
plt.grid()
sns.barplot(y='PaperName',x='GEN',data=paper_df)

# %%
plt.figure(figsize=(15,8))
plt.title("General category", color='r',size=15)
sns.barplot(y='PaperName',x='GEN',data=paper_df.head(10))

# %%
plt.figure(figsize=(15,8))
plt.title("General category", color='r',size=15)
plt.xticks(rotation=0)
plt.grid()
plt.scatter(y='PaperName',x='GEN',data=paper_df.head(30))

# %% [markdown]
# # For OBC Category

# %%
obc_var=['PaperName','OBC']
OBC_df=raw_data[obc_var]

# %%
OBC_df
# Out:
#                                     PaperName    OBC
# 0                               Life Sciences  28.50
# 1                           Civil Engineering  29.60
# 2                      Electrical Engineering  30.00
# 3                                       CS_IT  25.60
# 4                      Mechanical Engineering  30.60
# ..                                        ...    ...
# 88                     Electrical Engineering  22.50
# 89  Electronics and Communication Engineering  22.50
# 90                                      CS_IT  22.50
# 91                Instrumentation Engineering  22.90
# 92      Production and Industrial Engineering  24.14
#
# [93 rows x 2 columns]

# %%
OBC_df.PaperName.value_counts()
# Out:
# Electrical Engineering                        6
# Civil Engineering                             6
# Mechanical Engineering                        6
# Production and Industrial Engineering         5
# CS_IT                                         5
# Chemical Engineering                          4
# Electronics and Communication Engineering     4
# Biotechnology                                 4
# Instrumentation Engineering                   4
# Architecture and Planning                     3
# Metallurgical Engineering                     3
# Life Sciences                                 3
# Mining Engineering                            3
# Textile Engineering and Fibre Science         3
# Physics                                       3
# Petroleum Engineering                         3
# Aerospace Engineering                         3
# Ecology and Evolution                         3
# Agricultural Engineering                      3
# Chemistry                                     3
# Mathematics                                   3
# Statistics                                    2
# Geology and Geophysics                        2
# Engineering Sciences                          2
# Biomedical Engineering                        1
# Computer Science & Information Technology     1
# Instrumentation Engineering                   1
# Electronics and Communication                 1
# Electronics and Communication Engineering     1
# Engineering Sciences Minor                    1
# Geology                                       1
# Name: PaperName, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.title("OBC Category", color='r',size=15)
plt.grid(color='r')
sns.barplot(y='PaperName',x='OBC',palette="Blues_d",data=OBC_df.head(10))

# %% [markdown]
# # For SC/ST Category

# %%
tc_var=['PaperName','SC_ST']
tc_df=raw_data[tc_var]

# %%
tc_df.head()
# Out:
#                 PaperName  SC_ST
# 0           Life Sciences   21.1
# 1       Civil Engineering   21.9
# 2  Electrical Engineering   22.2
# 3                   CS_IT   19.0
# 4  Mechanical Engineering   22.6

# %%
update=tc_df.drop(2)
update
# Out:
#                                     PaperName  SC_ST
# 0                               Life Sciences  21.10
# 1                           Civil Engineering  21.90
# 3                                       CS_IT  19.00
# 4                      Mechanical Engineering  22.60
# 5                       Petroleum Engineering  26.50
# ..                                        ...    ...
# 88                     Electrical Engineering  16.67
# 89  Electronics and Communication Engineering  16.67
# 90                                      CS_IT  16.67
# 91                Instrumentation Engineering  16.96
# 92      Production and Industrial Engineering  17.88
#
# [92 rows x 2 columns]

# %%
update.head()
# Out:
#                 PaperName  SC_ST
# 0           Life Sciences   21.1
# 1       Civil Engineering   21.9
# 3                   CS_IT   19.0
# 4  Mechanical Engineering   22.6
# 5   Petroleum Engineering   26.5

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=70)
plt.grid(color='black')
sns.barplot(y='PaperName',x='SC_ST',data=tc_df.iloc[15:30])

# %%
new=raw_data.drop(raw_data[raw_data.Year<=2017].index,inplace=True)

# %%
raw_data
# Out:
#                                 PaperName Paper Code   GEN   OBC  SC_ST  Year
# 0                           Life Sciences         XL  31.7  28.5   21.1  2020
# 1                       Civil Engineering         CE  32.9  29.6   21.9  2020
# 2                  Electrical Engineering         EE  33.4  30.0   22.2  2020
# 3                                   CS_IT         CS  28.5  25.6   19.0  2020
# 4                  Mechanical Engineering         ME  34.0  30.6   22.6  2020
# ..                                    ...        ...   ...   ...    ...   ...
# 66                                Physics         PH  29.0  26.1   19.3  2018
# 67  Production and Industrial Engineering         PI  32.0  28.8   21.3  2018
# 68  Textile Engineering and Fibre Science         TF  32.2  28.9   21.4  2018
# 69                   Engineering Sciences         XE  31.5  28.3   21.0  2018
# 70                          Life Sciences         XL  29.9  26.9   19.9  2018
#
# [71 rows x 6 columns]

# %%
new_var=raw_data[['PaperName','GEN','OBC','Year']]
paper=raw_data.PaperName=='CS_IT'

# %%
paper_df=new_var[paper]
cs_df=paper_df.sort_values(by=['Year','PaperName'],ascending=False)
cs_df
# Out:
#    PaperName   GEN   OBC  Year
# 3      CS_IT  28.5  25.6  2020
# 27     CS_IT  29.5  26.6  2019
# 54     CS_IT  25.0  22.5  2018

# %%
raw_data.duplicated().sum()
# Out:
# 0
