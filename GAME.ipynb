# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
read1=pd.read_csv('vgsales.csv')

# %%
read1
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
read1.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
read1.drop(['Rank'],axis=1,inplace=True)

# %%
read1
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
read1.Year.max()
# Out:
# 2020.0

# %%
read1.Year.min()
# Out:
# 1980.0

# %%
var1=['Year','Name','Publisher','Genre']
new_df=read1[var1]

# %%
new_df
# Out:
#          Year                                              Name   Publisher  \
# 0      2006.0                                        Wii Sports    Nintendo
# 1      1985.0                                 Super Mario Bros.    Nintendo
# 2      2008.0                                    Mario Kart Wii    Nintendo
# 3      2009.0                                 Wii Sports Resort    Nintendo
# 4      1996.0                          Pokemon Red/Pokemon Blue    Nintendo
# ...       ...                                               ...         ...
# 16593  2002.0                Woody Woodpecker in Crazy Castle 5       Kemco
# 16594  2003.0                     Men in Black II: Alien Escape  Infogrames
# 16595  2008.0  SCORE International Baja 1000: The Official Game  Activision
# 16596  2010.0                                        Know How 2    7G//AMES
# 16597  2003.0                                  Spirits & Spells     Wanadoo
#
#               Genre
# 0            Sports
# ...

# %%
new_df.sort_values(by=['Year'],ascending=False).head(10)
# Out:
#          Year                                              Name  \
# 5957   2020.0                            Imagine: Makeup Artist
# 14390  2017.0  Phantasy Star Online 2 Episode 4: Deluxe Package
# 16241  2017.0  Phantasy Star Online 2 Episode 4: Deluxe Package
# 16438  2017.0                  Brothers Conflict: Precious Baby
# 8293   2016.0                      Shin Megami Tensei IV: Final
# 13647  2016.0                                     Hitman (2016)
# 13596  2016.0      Card Fight!! Vanguard G: Stride to Victory!!
# 13602  2016.0        Refrain no Chika Meikyuu to Majo no Ryodan
# 13614  2016.0                  Utawarerumono: Futari no Hakuoro
# 13620  2016.0                 Kamen Rider: Battride War Genesis
#
#                   Publisher         Genre
# 5957                Ubisoft    Simulation
# 14390                  Sega  Role-Playing
# 16241                  Sega  Role-Playing
# 16438          Idea Factory        Action
# 8293            Deep Silver  Role-Playing
# ...

# %% [markdown]
# data has been updated in 2020 after 2017 , so we have to remove it.....

# %%
read1.drop(read1[read1.Year>2017].index, inplace=True)

# %%
read1.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16326.000000  16597.000000  16597.000000  16597.000000  16597.000000
# mean    2006.405611      0.264667      0.146661      0.077786      0.048065
# std        5.828189      0.816708      0.505365      0.309299      0.188594
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2017.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales
# count  16597.000000
# mean       0.537456
# std        1.555074
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.740000

# %%
read1.sort_values(by=['Year'],ascending=False).head(10)
# Out:
#                                                    Name Platform    Year  \
# 16438                  Brothers Conflict: Precious Baby      PSV  2017.0
# 16241  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV  2017.0
# 14390  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4  2017.0
# 3145                                           NBA 2K17     XOne  2016.0
# 15184                      Sengoku Otome: Legend Battle      PSV  2016.0
# 16260                                           Paragon      PS4  2016.0
# 15166                Aegis of Earth: Protonovus Assault      PS4  2016.0
# 9250                                    Far Cry: Primal       PC  2016.0
# 5056                                            FIFA 17      PS3  2016.0
# 16252                     The Book of Unwritten Tales 2     WiiU  2016.0
#
#               Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16438        Action          Idea Factory      0.00      0.00      0.01
# ...
