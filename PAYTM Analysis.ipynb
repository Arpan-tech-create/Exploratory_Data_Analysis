# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.size']=14

sns.set_style('darkgrid')

# %%
raw_data=pd.read_csv('Paytm_Statement_Jul2022_9978624015.csv')
raw_data
# Out:
#                    Date         Activity  \
# 0   31/07/2022 19:22:25   Paid for order
# 1   31/07/2022 11:33:08   Paid for order
# 2   31/07/2022 11:31:10  Added to wallet
# 3   31/07/2022 08:21:33   Paid for order
# 4   30/07/2022 19:14:56   Paid for order
# ..                  ...              ...
# 75  06/07/2022 18:20:23   Paid for order
# 76  06/07/2022 11:02:46   Paid for order
# 77  06/07/2022 09:00:52  Added to wallet
# 78  05/07/2022 18:30:00   Paid for order
# 79  02/07/2022 21:47:49       Money sent
#
#                             Source/Destination  Wallet Txn ID  \
# 0   ZOMATO LIMITED Order #ZTD-22-E94A108CC2152    41535882059
# 1   ZOMATO LIMITED Order #ZTD-22-C4DF18EF53C8B    41528642299
# 2                     Paytm Order #18723945711    41528610550
# 3        Shiv Bakery Order #202207310821270030    41526457975
# 4   ZOMATO LIMITED Order #ZTD-22-D64AAF5D8FA8F    41520959879
# ..                                         ...            ...
# 75  ZOMATO LIMITED Order #ZTD-22-AB42A262C6C4D    41170023288
# 76  ZOMATO LIMITED Order #ZTD-22-08521BE55686F    41163827813
# 77                    Paytm Order #18509252566    41162381041
# 78  ZOMATO LIMITED Order #ZTD-22-354D02FE3C2E4    41155808187
# 79                  Order #SM_963F8331A463581B    41116351962
#
#                        Comment   Debit  Credit  Transaction Breakup   Status
# 0                          NaN  174.40     NaN                  NaN  SUCCESS
# 1                          NaN  167.05     NaN                  NaN  SUCCESS
# 2                          NaN     NaN  1000.0                  NaN  SUCCESS
# 3                          NaN   35.00     NaN                  NaN  SUCCESS
# 4                          NaN  121.40     NaN                  NaN  SUCCESS
# ..                         ...     ...     ...                  ...      ...
# 75                         NaN  137.15     NaN                  NaN  SUCCESS
# 76                         NaN  311.95     NaN                  NaN  SUCCESS
# 77                         NaN     NaN   800.0                  NaN  SUCCESS
# 78                         NaN  187.05     NaN                  NaN  SUCCESS
# 79  From: Bhoi Arpan To: Shrut  100.00     NaN                  NaN  SUCCESS
#
# [80 rows x 9 columns]

# %%
raw_data.shape
# Out:
# (80, 7)

# %%
raw_data.Status.value_counts()
# Out:
# SUCCESS    80
# Name: Status, dtype: int64

# %% [markdown]
# There Are Total 80 Entries in The Dataset & Status Value is Always be Success. it Shows The  Consistency Of PAYTM .

# %%
from IPython.display import Image
Image(filename='paytm.jpg')

# %%
raw_data.rename(columns={'Source/Destination':'Source'},inplace=True)

# %%
raw_data
# Out:
#                    Date         Activity  \
# 0   31/07/2022 19:22:25   Paid for order
# 1   31/07/2022 11:33:08   Paid for order
# 2   31/07/2022 11:31:10  Added to wallet
# 3   31/07/2022 08:21:33   Paid for order
# 4   30/07/2022 19:14:56   Paid for order
# ..                  ...              ...
# 75  06/07/2022 18:20:23   Paid for order
# 76  06/07/2022 11:02:46   Paid for order
# 77  06/07/2022 09:00:52  Added to wallet
# 78  05/07/2022 18:30:00   Paid for order
# 79  02/07/2022 21:47:49       Money sent
#
#                                         Source  Wallet Txn ID  \
# 0   ZOMATO LIMITED Order #ZTD-22-E94A108CC2152    41535882059
# 1   ZOMATO LIMITED Order #ZTD-22-C4DF18EF53C8B    41528642299
# 2                     Paytm Order #18723945711    41528610550
# 3        Shiv Bakery Order #202207310821270030    41526457975
# 4   ZOMATO LIMITED Order #ZTD-22-D64AAF5D8FA8F    41520959879
# ..                                         ...            ...
# 75  ZOMATO LIMITED Order #ZTD-22-AB42A262C6C4D    41170023288
# 76  ZOMATO LIMITED Order #ZTD-22-08521BE55686F    41163827813
# 77                    Paytm Order #18509252566    41162381041
# 78  ZOMATO LIMITED Order #ZTD-22-354D02FE3C2E4    41155808187
# 79                  Order #SM_963F8331A463581B    41116351962
#
#                        Comment   Debit  Credit  Transaction Breakup   Status
# 0                          NaN  174.40     NaN                  NaN  SUCCESS
# 1                          NaN  167.05     NaN                  NaN  SUCCESS
# 2                          NaN     NaN  1000.0                  NaN  SUCCESS
# 3                          NaN   35.00     NaN                  NaN  SUCCESS
# 4                          NaN  121.40     NaN                  NaN  SUCCESS
# ..                         ...     ...     ...                  ...      ...
# 75                         NaN  137.15     NaN                  NaN  SUCCESS
# 76                         NaN  311.95     NaN                  NaN  SUCCESS
# 77                         NaN     NaN   800.0                  NaN  SUCCESS
# 78                         NaN  187.05     NaN                  NaN  SUCCESS
# 79  From: Bhoi Arpan To: Shrut  100.00     NaN                  NaN  SUCCESS
#
# [80 rows x 9 columns]

# %%
raw_data.drop(['Comment','Transaction Breakup'],axis=1,inplace=True)

# %%
raw_data
# Out:
#                    Date         Activity  \
# 0   31/07/2022 19:22:25   Paid for order
# 1   31/07/2022 11:33:08   Paid for order
# 2   31/07/2022 11:31:10  Added to wallet
# 3   31/07/2022 08:21:33   Paid for order
# 4   30/07/2022 19:14:56   Paid for order
# ..                  ...              ...
# 75  06/07/2022 18:20:23   Paid for order
# 76  06/07/2022 11:02:46   Paid for order
# 77  06/07/2022 09:00:52  Added to wallet
# 78  05/07/2022 18:30:00   Paid for order
# 79  02/07/2022 21:47:49       Money sent
#
#                                         Source  Wallet Txn ID   Debit  Credit  \
# 0   ZOMATO LIMITED Order #ZTD-22-E94A108CC2152    41535882059  174.40     NaN
# 1   ZOMATO LIMITED Order #ZTD-22-C4DF18EF53C8B    41528642299  167.05     NaN
# 2                     Paytm Order #18723945711    41528610550     NaN  1000.0
# 3        Shiv Bakery Order #202207310821270030    41526457975   35.00     NaN
# 4   ZOMATO LIMITED Order #ZTD-22-D64AAF5D8FA8F    41520959879  121.40     NaN
# ..                                         ...            ...     ...     ...
# 75  ZOMATO LIMITED Order #ZTD-22-AB42A262C6C4D    41170023288  137.15     NaN
# 76  ZOMATO LIMITED Order #ZTD-22-08521BE55686F    41163827813  311.95     NaN
# 77                    Paytm Order #18509252566    41162381041     NaN   800.0
# 78  ZOMATO LIMITED Order #ZTD-22-354D02FE3C2E4    41155808187  187.05     NaN
# 79                  Order #SM_963F8331A463581B    41116351962  100.00     NaN
#
#      Status
# 0   SUCCESS
# 1   SUCCESS
# 2   SUCCESS
# 3   SUCCESS
# 4   SUCCESS
# ..      ...
# 75  SUCCESS
# 76  SUCCESS
# 77  SUCCESS
# 78  SUCCESS
# 79  SUCCESS
#
# [80 rows x 7 columns]

# %%
raw_data.Activity.value_counts()
# Out:
# Paid for order      66
# Added to wallet     12
# Refund for order     1
# Money sent           1
# Name: Activity, dtype: int64

# %%
plt.figure(figsize=(15,7))
raw_data['Activity'].value_counts().head(10).plot.pie(autopct='%1.1f%%')
plt.legend(raw_data['Activity'].value_counts(),loc='upper left')

# %%
raw_data.Credit.sum()
# Out:
# 10599.8

# %%
raw_data.Source.value_counts()
# Out:
# ZOMATO LIMITED Order #ZTD-22-E60B4C321B47E    2
# ZOMATO LIMITED Order #ZTD-22-6D90407FD8CD5    1
# ZOMATO LIMITED Order #ZTD-22-124C7D4D814A3    1
# ZOMATO LIMITED Order #ZTD-22-AAAB71EC3C013    1
# ZOMATO LIMITED Order #ZTD-22-11213125AB11B    1
#                                              ..
# ZOMATO LIMITED Order #ZTD-22-B44F5D9814C64    1
# Paytm Order #18538031627                      1
# ZOMATO LIMITED Order #ZTD-22-9AB1EF78B0236    1
# Amitbhai patel Order #202207240725460075      1
# ZOMATO LIMITED Order #ZTD-22-C3B5448416FDA    1
# Name: Source, Length: 79, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.distplot(raw_data['Debit'],color='r').set(title='Debits')
# Out:
# [Text(0.5, 1.0, 'Debits')]

# %%
plt.figure(figsize=(15,7))
sns.distplot(raw_data['Credit'],color='g').set(title='Credits')
# Out:
# [Text(0.5, 1.0, 'Credits')]

# %%
plt.figure(figsize=(15,7))
ax1 = plt.subplot()
ax2 = ax1.twinx()
sns.scatterplot(x='Activity',y='Debit',color='r',data=raw_data,ax=ax1)
sns.scatterplot(x='Activity',y='Credit',color='g',data=raw_data,ax=ax2)
ax2.tick_params(axis='y', colors='g')
ax1.tick_params(axis='x',rotation=90)

# %%
val=raw_data[['Date','Source','Debit']]
val_df=raw_data.Activity=='Paid for order'

# %%
fetch=val[val_df]
fetch_df=fetch.sort_values(by=['Debit'],ascending=True).head(10)
fetch_df
# Out:
#                    Date                                      Source  Debit
# 29  22/07/2022 09:57:36       Shiv Bakery Order #202207220957320037   30.0
# 3   31/07/2022 08:21:33       Shiv Bakery Order #202207310821270030   35.0
# 6   30/07/2022 08:52:51       Shiv Bakery Order #202207300852470051   35.0
# 23  24/07/2022 07:25:51    Amitbhai patel Order #202207240725460075   78.0
# 42  17/07/2022 11:32:12  ZOMATO LIMITED Order #ZTD-22-FB0A5E97F8869   81.5
# 63  09/07/2022 11:31:05  ZOMATO LIMITED Order #ZTD-22-158BC3D09FB12   81.5
# 37  18/07/2022 11:55:44  ZOMATO LIMITED Order #ZTD-22-C0FD81DC03E24   81.5
# 24  23/07/2022 17:43:39  ZOMATO LIMITED Order #ZTD-22-374CB29CECD2D   92.0
# 69  08/07/2022 11:01:23  ZOMATO LIMITED Order #ZTD-22-C3B5448416FDA   92.0
# 22  24/07/2022 16:34:03  ZOMATO LIMITED Order #ZTD-22-7164C66D413C5   92.0

# %%
fetch_df.Debit.sum()
# Out:
# 698.5

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=80)
sns.barplot(x='Source',y='Debit',data=fetch_df,palette='magma')

# %%
raw_data['Credit'].value_counts()
# Out:
# 1000.0    5
# 800.0     4
# 900.0     2
# 99.8      1
# 500.0     1
# Name: Credit, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=40)
sns.countplot(x='Credit',data=raw_data,palette='Blues_d').set(title='Credit_Counts')
# Out:
# [Text(0.5, 1.0, 'Credit_Counts')]
