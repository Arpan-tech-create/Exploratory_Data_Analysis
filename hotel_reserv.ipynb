# %%
import pandas as  pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.set_style('darkgrid')
plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(15,8)

# %%
data=pd.read_csv('E:\SYSTEM\Downloads\hotel_bookings.csv')

# %%
data
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0      Resort Hotel            0               2015               July
# 1      Resort Hotel            0               2015               July
# 2      Resort Hotel            0               2015               July
# 3      Resort Hotel            0               2015               July
# 4      Resort Hotel            0               2015               July
# ...             ...          ...                ...                ...
# 40055    City Hotel            0               2015             August
# 40056    City Hotel            0               2015             August
# 40057    City Hotel            0               2015             August
# 40058    City Hotel            0               2015             August
# 40059    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
data
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 2392   Resort Hotel            0               2015            October
# 2697   Resort Hotel            0               2015            October
# 2867   Resort Hotel            0               2015           November
# 2877   Resort Hotel            0               2015           November
# 2878   Resort Hotel            0               2015           November
# ...             ...          ...                ...                ...
# 37492  Resort Hotel            0               2017               June
# 38400  Resort Hotel            0               2017               July
# 39426  Resort Hotel            0               2017             August
# 39737  Resort Hotel            0               2017             August
# 40040    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
data.isnull().sum()
# Out:
# hotel                            0
# is_canceled                      0
# arrival_date_year                0
# arrival_date_month               0
# arrival_date_day_of_month        0
# stays_in_weekend_nights          0
# stays_in_week_nights             0
# adults                           0
# children                         0
# country                        464
# market_segment                   0
# is_repeated_guest                0
# reserved_room_type               0
# assigned_room_type               0
# deposit_type                     0
# agent                         8213
# company                      36951
# customer_type                    0
# reservation_status               0
# reservation_status_date          0
# dtype: int64

# %%
data.drop(data[data.country.isnull()].index,inplace=True)
data.drop(data[data.agent.isnull()].index,inplace=True)
data.drop(data[data.company.isnull()].index,inplace=True)

# %%
data.duplicated().sum()
# Out:
# 39

# %%
dupli=data.loc[data.duplicated(),:]
dupli
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 2882   Resort Hotel            0               2015           November
# 2915   Resort Hotel            0               2015           November
# 2916   Resort Hotel            0               2015           November
# 2917   Resort Hotel            0               2015           November
# 2942   Resort Hotel            0               2015           November
# 2950   Resort Hotel            0               2015           November
# 2953   Resort Hotel            0               2015           November
# 2969   Resort Hotel            0               2015           November
# 2970   Resort Hotel            0               2015           November
# 2984   Resort Hotel            1               2015           November
# 3048   Resort Hotel            0               2015           November
# 3051   Resort Hotel            0               2015           November
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 2392   Resort Hotel            0               2015            October
# 2697   Resort Hotel            0               2015            October
# 2867   Resort Hotel            0               2015           November
# 2877   Resort Hotel            0               2015           November
# 2878   Resort Hotel            0               2015           November
# ...             ...          ...                ...                ...
# 37492  Resort Hotel            0               2017               June
# 38400  Resort Hotel            0               2017               July
# 39426  Resort Hotel            0               2017             August
# 39737  Resort Hotel            0               2017             August
# 40040    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
data.hotel.value_counts()
# Out:
# Resort Hotel    131
# City Hotel        1
# Name: hotel, dtype: int64

# %%
data.reservation_status.value_counts()
# Out:
# Check-Out    118
# Canceled      11
# No-Show        3
# Name: reservation_status, dtype: int64

# %%
hotel=data[data.reservation_status=='No-Show']

# %%
hotel
# Out:
#              hotel  is_canceled  arrival_date_year arrival_date_month  \
# 2983  Resort Hotel            1               2015           November
# 2988  Resort Hotel            1               2015           November
# 5700  Resort Hotel            1               2016                May
#
#       arrival_date_day_of_month  stays_in_weekend_nights  \
# 2983                          9                        1
# 2988                          9                        2
# 5700                         11                        0
#
#       stays_in_week_nights  adults  children country market_segment  \
# 2983                     5       1         0     PRT      Corporate
# 2988                     5       2         0     PRT      Corporate
# 5700                     1       1         0     PRT         Direct
#
#       is_repeated_guest reserved_room_type assigned_room_type deposit_type  \
# 2983                  0                  A                  A   No Deposit
# ...

# %%
data.describe()
# Out:
#        is_canceled  arrival_date_year  arrival_date_day_of_month  \
# count   132.000000         132.000000                 132.000000
# mean      0.106061        2015.348485                   9.833333
# std       0.309088           0.653643                   7.150686
# min       0.000000        2015.000000                   1.000000
# 25%       0.000000        2015.000000                   4.750000
# 50%       0.000000        2015.000000                   8.000000
# 75%       0.000000        2015.250000                  12.000000
# max       1.000000        2017.000000                  30.000000
#
#        stays_in_weekend_nights  stays_in_week_nights      adults    children  \
# count               132.000000            132.000000  132.000000  132.000000
# mean                  1.643939              5.053030    1.409091    0.037879
# std                   1.625806              3.800993    0.508771    0.259339
# ...

# %%
data.is_canceled.value_counts()
# Out:
# 0    118
# 1     14
# Name: is_canceled, dtype: int64

# %%
data1=data[['arrival_date_year','reservation_status','is_canceled','arrival_date_month','is_repeated_guest']]
data1_df=data.is_canceled==0

# %%
new_df1=data1[data1_df]
new_df12=new_df1.sort_values(by=['arrival_date_year'],ascending=False)
new_df12
# Out:
#        arrival_date_year reservation_status  is_canceled arrival_date_month  \
# 14383               2017          Check-Out            0            January
# 34086               2017          Check-Out            0              March
# 18628               2017          Check-Out            0              March
# 16645               2017          Check-Out            0            January
# 32385               2017          Check-Out            0            January
# ...                  ...                ...          ...                ...
# 3046                2015          Check-Out            0           November
# 3044                2015          Check-Out            0           November
# 3043                2015          Check-Out            0           November
# 3037                2015          Check-Out            0           November
# 40040               2015          Check-Out            0             August
#
#        is_repeated_guest
# 14383                  0
# ...

# %%
year=new_df12[['arrival_date_year','is_repeated_guest','arrival_date_month']]
year_df=new_df12.arrival_date_year==2017

# %%
Now=year[year_df]
Now_df=Now.sort_values(by=['is_repeated_guest'],ascending=False)
Now_df
# Out:
#        arrival_date_year  is_repeated_guest arrival_date_month
# 18628               2017                  1              March
# 16645               2017                  1            January
# 14383               2017                  0            January
# 34086               2017                  0              March
# 32385               2017                  0            January
# 33943               2017                  0              March
# 31758               2017                  0            January
# 37288               2017                  0               June
# 37492               2017                  0               June
# 38400               2017                  0               July
# 39426               2017                  0             August
# 39737               2017                  0             August

# %%
new_df12.arrival_date_year.value_counts()
# Out:
# 2015    88
# 2016    18
# 2017    12
# Name: arrival_date_year, dtype: int64

# %%
arrives=data.arrival_date_month.value_counts()
arrives
# Out:
# November     93
# October       7
# May           7
# January       5
# March         4
# August        4
# July          3
# December      3
# June          3
# September     1
# April         1
# February      1
# Name: arrival_date_month, dtype: int64

# %%
sns.barplot(x=arrives.index,y=arrives)

# %% [markdown]
# so , maximum number of arrival happened in November Month

# %%
years=data.arrival_date_year.value_counts()
years
# Out:
# 2015    99
# 2016    20
# 2017    13
# Name: arrival_date_year, dtype: int64

# %%
data
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 2392   Resort Hotel            0               2015            October
# 2697   Resort Hotel            0               2015            October
# 2867   Resort Hotel            0               2015           November
# 2877   Resort Hotel            0               2015           November
# 2878   Resort Hotel            0               2015           November
# ...             ...          ...                ...                ...
# 37492  Resort Hotel            0               2017               June
# 38400  Resort Hotel            0               2017               July
# 39426  Resort Hotel            0               2017             August
# 39737  Resort Hotel            0               2017             August
# 40040    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
data
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 2392   Resort Hotel            0               2015            October
# 2697   Resort Hotel            0               2015            October
# 2867   Resort Hotel            0               2015           November
# 2877   Resort Hotel            0               2015           November
# 2878   Resort Hotel            0               2015           November
# ...             ...          ...                ...                ...
# 37492  Resort Hotel            0               2017               June
# 38400  Resort Hotel            0               2017               July
# 39426  Resort Hotel            0               2017             August
# 39737  Resort Hotel            0               2017             August
# 40040    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
data.shape
# Out:
# (132, 20)

# %%
data.deposit_type.value_counts()
# Out:
# No Deposit    129
# Refundable      2
# Non Refund      1
# Name: deposit_type, dtype: int64

# %%
DEPOSIT=data.hotel[data.deposit_type=='Refundable']
DEPOSIT
# Out:
# 24226    Resort Hotel
# 24278    Resort Hotel
# Name: hotel, dtype: object

# %%
nonrefund=data.hotel[data.deposit_type=='Non Refund']
nonrefund
# Out:
# 18264    Resort Hotel
# Name: hotel, dtype: object

# %%
data.customer_type.value_counts()
# Out:
# Transient-Party    97
# Transient          27
# Group               5
# Contract            3
# Name: customer_type, dtype: int64

# %%
plt.title('Customer_TYPE')
plt.pie(data.customer_type.value_counts(),labels=data.customer_type.value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
data.market_segment.value_counts()
# Out:
# Corporate        95
# Direct           14
# Online TA        13
# Offline TA/TO     8
# Groups            1
# Complementary     1
# Name: market_segment, dtype: int64

# %%
plt.xticks(rotation=70)
sns.barplot(x='market_segment',y='company',hue='hotel',data=data)

# %%
data.reservation_status.value_counts()
# Out:
# Check-Out    118
# Canceled      11
# No-Show        3
# Name: reservation_status, dtype: int64

# %%
custom_type=data.customer_type[data.reservation_status=='Check-Out']
custom_type.value_counts()
# Out:
# Transient-Party    85
# Transient          25
# Group               5
# Contract            3
# Name: customer_type, dtype: int64

# %%
reser_cancel=data.customer_type[data.reservation_status=='Canceled']
reser_cancel.value_counts()
# Out:
# Transient-Party    9
# Transient          2
# Name: customer_type, dtype: int64

# %%
noshow=data.customer_type[data.reservation_status=='No-Show']
noshow.value_counts()
# Out:
# Transient-Party    3
# Name: customer_type, dtype: int64

# %%
data.hotel.value_counts()
# Out:
# Resort Hotel    131
# City Hotel        1
# Name: hotel, dtype: int64
