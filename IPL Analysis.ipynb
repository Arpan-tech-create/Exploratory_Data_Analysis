# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
read1=pd.read_csv("IPL Matches 2008-2020.csv")
read1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
read1.shape
# Out:
# (816, 17)

# %%
read1.drop(['id'],axis=1,inplace=True)

# %%
read1
# Out:
#            city        date player_of_match  \
# 0     Bangalore  2008-04-18     BB McCullum
# 1    Chandigarh  2008-04-19      MEK Hussey
# 2         Delhi  2008-04-19     MF Maharoof
# 3        Mumbai  2008-04-20      MV Boucher
# 4       Kolkata  2008-04-20       DJ Hussey
# ..          ...         ...             ...
# 811       Dubai  2020-09-28  AB de Villiers
# 812       Dubai  2020-11-05       JJ Bumrah
# 813   Abu Dhabi  2020-11-06   KS Williamson
# 814   Abu Dhabi  2020-11-08      MP Stoinis
# 815       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ...

# %%
read1.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
read1.drop(read1[read1.city.isnull()].index, inplace=True)
read1.drop(read1[read1.player_of_match.isnull()].index, inplace=True)
read1.drop(read1[read1.method.isnull()].index, inplace=True)

# %%
read1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 40 to 667
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               19 non-null     int64
#  1   city             19 non-null     object
#  2   date             19 non-null     object
#  3   player_of_match  19 non-null     object
#  4   venue            19 non-null     object
#  5   neutral_venue    19 non-null     int64
#  6   team1            19 non-null     object
#  7   team2            19 non-null     object
#  8   toss_winner      19 non-null     object
#  9   toss_decision    19 non-null     object
#  10  winner           19 non-null     object
#  11  result           19 non-null     object
#  12  result_margin    19 non-null     float64
#  13  eliminator       19 non-null     object
#  14  method           19 non-null     object
#  15  umpire1          19 non-null     object
# ...

# %%
count=read1['winner'].value_counts()
print(count)
# Out:
# Kolkata Knight Riders          4
# Royal Challengers Bangalore    3
# Chennai Super Kings            2
# Kings XI Punjab                2
# Delhi Daredevils               2
# Rising Pune Supergiants        2
# Sunrisers Hyderabad            2
# Kochi Tuskers Kerala           1
# Rajasthan Royals               1
# Name: winner, dtype: int64

# %%
barchart=['team1','winner']
dataf=read1[barchart]
x=dataf["team1"]
y=dataf["winner"].value_counts()
plt.figure(figsize=(20,8))
plt.xlabel("TEAMS",fontsize=10)
plt.ylabel("Winner",fontsize=10)
sns.barplot(x,y,data=dataf)

# %%
var1=['winner','team1']

new_df1=read1[var1]

# %%
new_df1
# Out:
#                           winner                        team1
# 0          Kolkata Knight Riders  Royal Challengers Bangalore
# 1            Chennai Super Kings              Kings XI Punjab
# 2               Delhi Daredevils             Delhi Daredevils
# 3    Royal Challengers Bangalore               Mumbai Indians
# 4          Kolkata Knight Riders        Kolkata Knight Riders
# ..                           ...                          ...
# 811  Royal Challengers Bangalore  Royal Challengers Bangalore
# 812               Mumbai Indians               Mumbai Indians
# 813          Sunrisers Hyderabad  Royal Challengers Bangalore
# 814               Delhi Capitals               Delhi Capitals
# 815               Mumbai Indians               Delhi Capitals
#
# [816 rows x 2 columns]

# %%
new_df1['winner'].value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=60)
plt.title("Popular TEAM")
sns.barplot(x=new_df1.index,y=new_df1);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     543             try:
# --> 544                 order = values.cat.categories
#     545             except (TypeError, AttributeError):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     546                 try:
# --> 547                     order = values.unique()
# ...

# %%
read1.head(10)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
# 5  335987      Jaipur  2008-04-21       SR Watson
# 6  335988   Hyderabad  2008-04-22        V Sehwag
# 7  335989     Chennai  2008-04-23       ML Hayden
# 8  335990   Hyderabad  2008-04-24       YK Pathan
# 9  335991  Chandigarh  2008-04-25   KC Sangakkara
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
# ...

# %%
new=read1.winner.value_counts
new
# Out:
# <bound method IndexOpsMixin.value_counts of 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 811    Royal Challengers Bangalore
# 812                 Mumbai Indians
# 813            Sunrisers Hyderabad
# 814                 Delhi Capitals
# 815                 Mumbai Indians
# Name: winner, Length: 816, dtype: object>

# %%
read1.tail(2)
# Out:
#           id       city        date player_of_match  \
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue           team1  \
# 814                 Sheikh Zayed Stadium              0  Delhi Capitals
# 815  Dubai International Cricket Stadium              0  Delhi Capitals
#
#                    team2     toss_winner toss_decision          winner  \
# 814  Sunrisers Hyderabad  Delhi Capitals           bat  Delhi Capitals
# 815       Mumbai Indians  Delhi Capitals           bat  Mumbai Indians
#
#       result  result_margin eliminator method      umpire1      umpire2
# 814     runs           17.0          N    NaN   PR Reiffel       S Ravi
# 815  wickets            5.0          N    NaN  CB Gaffaney  Nitin Menon

# %%
new_df=['city','winner','date']
dataf=read1[new_df]

# %%
dataf
# Out:
#            city                       winner        date
# 0     Bangalore        Kolkata Knight Riders  2008-04-18
# 1    Chandigarh          Chennai Super Kings  2008-04-19
# 2         Delhi             Delhi Daredevils  2008-04-19
# 3        Mumbai  Royal Challengers Bangalore  2008-04-20
# 4       Kolkata        Kolkata Knight Riders  2008-04-20
# ..          ...                          ...         ...
# 811       Dubai  Royal Challengers Bangalore  2020-09-28
# 812       Dubai               Mumbai Indians  2020-11-05
# 813   Abu Dhabi          Sunrisers Hyderabad  2020-11-06
# 814   Abu Dhabi               Delhi Capitals  2020-11-08
# 815       Dubai               Mumbai Indians  2020-11-10
#
# [816 rows x 3 columns]

# %%
dataf.head(4)
# Out:
#          city                       winner        date
# 0   Bangalore        Kolkata Knight Riders  2008-04-18
# 1  Chandigarh          Chennai Super Kings  2008-04-19
# 2       Delhi             Delhi Daredevils  2008-04-19
# 3      Mumbai  Royal Challengers Bangalore  2008-04-20

# %%
print(read1[['team1','city']].head(15))
# Out:
#                           team1        city
# 0   Royal Challengers Bangalore   Bangalore
# 1               Kings XI Punjab  Chandigarh
# 2              Delhi Daredevils       Delhi
# 3                Mumbai Indians      Mumbai
# 4         Kolkata Knight Riders     Kolkata
# 5              Rajasthan Royals      Jaipur
# 6               Deccan Chargers   Hyderabad
# 7           Chennai Super Kings     Chennai
# 8               Deccan Chargers   Hyderabad
# 9               Kings XI Punjab  Chandigarh
# 10  Royal Challengers Bangalore   Bangalore
# 11          Chennai Super Kings     Chennai
# 12               Mumbai Indians      Mumbai
# 13              Kings XI Punjab  Chandigarh
# 14  Royal Challengers Bangalore   Bangalore

# %%
read1.info
# Out:
# <bound method DataFrame.info of           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# ...

# %%
print(read1.iloc[2])
# Out:
# id                           335984
# city                          Delhi
# date                     2008-04-19
# player_of_match         MF Maharoof
# venue              Feroz Shah Kotla
# neutral_venue                     0
# team1              Delhi Daredevils
# team2              Rajasthan Royals
# toss_winner        Rajasthan Royals
# toss_decision                   bat
# winner             Delhi Daredevils
# result                      wickets
# result_margin                     9
# eliminator                        N
# method                          NaN
# umpire1                   Aleem Dar
# umpire2              GA Pratapkumar
# Name: 2, dtype: object

# %%
read1.iloc[5]
# Out:
# id                                 335987
# city                               Jaipur
# date                           2008-04-21
# player_of_match                 SR Watson
# venue              Sawai Mansingh Stadium
# neutral_venue                           0
# team1                    Rajasthan Royals
# team2                     Kings XI Punjab
# toss_winner               Kings XI Punjab
# toss_decision                         bat
# winner                   Rajasthan Royals
# result                            wickets
# result_margin                           6
# eliminator                              N
# method                                NaN
# umpire1                         Aleem Dar
# umpire2                         RB Tiffin
# Name: 5, dtype: object

# %%
print(read1.iloc[1:6])
# Out:
#        id        city        date player_of_match  \
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
# 5  335987      Jaipur  2008-04-21       SR Watson
#
#                                         venue  neutral_venue  \
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
# 5                      Sawai Mansingh Stadium              0
#
#                    team1                        team2          toss_winner  \
# 1        Kings XI Punjab          Chennai Super Kings  Chennai Super Kings
# 2       Delhi Daredevils             Rajasthan Royals     Rajasthan Royals
# ...

# %%
read1.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
read1.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
read1.head(3)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
# 2             Delhi Daredevils       Rajasthan Royals
#
#                    toss_winner toss_decision                 winner   result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders     runs
# 1          Chennai Super Kings           bat    Chennai Super Kings     runs
# ...

# %%
read1.shape

816 Rows , 17 columns
# Out:
# (816, 17)

# %%
read1.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
read1['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 106
# Kolkata Knight Riders           98
# Chennai Super Kings             97
# Royal Challengers Bangalore     87
# Rajasthan Royals                87
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             57
# Deccan Chargers                 43
# Pune Warriors                   20
# Delhi Capitals                  20
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: toss_winner, dtype: int64

# %%
read1['venue'].value_counts()
# Out:
# Eden Gardens                                            77
# Feroz Shah Kotla                                        74
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Rajiv Gandhi International Stadium, Uppal               64
# MA Chidambaram Stadium, Chepauk                         57
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Dubai International Cricket Stadium                     33
# Sheikh Zayed Stadium                                    29
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Maharashtra Cricket Association Stadium                 21
# Sharjah Cricket Stadium                                 18
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# M.Chinnaswamy Stadium                                   15
# ...

# %%
read1['winner'].value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
read1['player_of_match'].value_counts().head(10).keys()
# Out:
# Index(['AB de Villiers', 'CH Gayle', 'RG Sharma', 'DA Warner', 'MS Dhoni',
#        'SR Watson', 'YK Pathan', 'SK Raina', 'V Kohli', 'G Gambhir'],
#       dtype='object')

# %%
read1['winner'].value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.bar(list(read1['player_of_match'].value_counts().head(5).keys())),list(read1['player_of_match'].value_counts().head(5),color='b')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0ba9cdd50c37> in <module>
#       1 plt.figure(figsize=(15,8))
# ----> 2 plt.bar(list(read1['player_of_match'].value_counts().head(5).keys())),list(read1['player_of_match'].value_counts().head(5),color='b')
#       3 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
read1['player_of_match'].value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# CV Varun           1
# LJ Wright          1
# HF Gurney          1
# RS Bopara          1
# GJ Bailey          1
# Name: player_of_match, Length: 233, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.size'] = 12
plt.figure(figsize=(15,5))
sns.barplot(x="team1",y="result_margin",data=read1.sort_values(["toss_winner","toss_decision"]).head(10))
plt.xticks(rotation=40)
plt.xlabel("TEAMS")
plt.ylabel("WINS")
plt.title("Data Visualisation")
# Out:
# Text(0.5, 1.0, 'Data Visualisation')

# %%
read1['result'].value_counts()
# Out:
# wickets    435
# runs       364
# tie         13
# Name: result, dtype: int64

# %%
read1['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 106
# Kolkata Knight Riders           98
# Chennai Super Kings             97
# Royal Challengers Bangalore     87
# Rajasthan Royals                87
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             57
# Deccan Chargers                 43
# Pune Warriors                   20
# Delhi Capitals                  20
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: toss_winner, dtype: int64

# %%
new=['team1','team2','toss_winner','result','result_margin','winner']
new_df=read1[new]
print(new_df)
# Out:
#                            team1                        team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 811  Royal Challengers Bangalore               Mumbai Indians
# 812               Mumbai Indians               Delhi Capitals
# 813  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814               Delhi Capitals          Sunrisers Hyderabad
# 815               Delhi Capitals               Mumbai Indians
#
#                      toss_winner   result  result_margin  \
# 0    Royal Challengers Bangalore     runs          140.0
# 1            Chennai Super Kings     runs           33.0
# ...

# %%
new_df.sort_values(by=['toss_winner'],ascending=False).head(5)
# Out:
#                            team1                   team2          toss_winner  \
# 619          Sunrisers Hyderabad  Rising Pune Supergiant  Sunrisers Hyderabad
# 556      Rising Pune Supergiants     Sunrisers Hyderabad  Sunrisers Hyderabad
# 395             Rajasthan Royals     Sunrisers Hyderabad  Sunrisers Hyderabad
# 575                Gujarat Lions     Sunrisers Hyderabad  Sunrisers Hyderabad
# 576  Royal Challengers Bangalore     Sunrisers Hyderabad  Sunrisers Hyderabad
#
#       result  result_margin                  winner
# 619     runs           12.0  Rising Pune Supergiant
# 556     runs            4.0     Sunrisers Hyderabad
# 395  wickets            4.0        Rajasthan Royals
# 575  wickets            4.0     Sunrisers Hyderabad
# 576     runs            8.0     Sunrisers Hyderabad

# %%
read1['result_margin'].max()
# Out:
# 146.0

# %%
var=['team1','city','winner']
df=read1[var]
print(df)
# Out:
#                            team1        city                       winner
# 0    Royal Challengers Bangalore   Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab  Chandigarh          Chennai Super Kings
# 2               Delhi Daredevils       Delhi             Delhi Daredevils
# 3                 Mumbai Indians      Mumbai  Royal Challengers Bangalore
# 4          Kolkata Knight Riders     Kolkata        Kolkata Knight Riders
# ..                           ...         ...                          ...
# 811  Royal Challengers Bangalore       Dubai  Royal Challengers Bangalore
# 812               Mumbai Indians       Dubai               Mumbai Indians
# 813  Royal Challengers Bangalore   Abu Dhabi          Sunrisers Hyderabad
# 814               Delhi Capitals   Abu Dhabi               Delhi Capitals
# 815               Delhi Capitals       Dubai               Mumbai Indians
#
# [816 rows x 3 columns]

# %%
var=['team1','city','winner']
df=read1[var]
df.head()
# Out:
#                          team1        city                       winner
# 0  Royal Challengers Bangalore   Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab  Chandigarh          Chennai Super Kings
# 2             Delhi Daredevils       Delhi             Delhi Daredevils
# 3               Mumbai Indians      Mumbai  Royal Challengers Bangalore
# 4        Kolkata Knight Riders     Kolkata        Kolkata Knight Riders

# %%
df['team1'].value_counts()
# Out:
# Royal Challengers Bangalore    108
# Mumbai Indians                  97
# Kolkata Knight Riders           95
# Chennai Super Kings             94
# Kings XI Punjab                 92
# Delhi Daredevils                83
# Rajasthan Royals                70
# Sunrisers Hyderabad             59
# Deccan Chargers                 39
# Pune Warriors                   23
# Delhi Capitals                  19
# Gujarat Lions                   16
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: team1, dtype: int64

# %%
df['winner'].value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64
