# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

sns.set_style('darkgrid')
plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(13,7)

# %%
raw_data=pd.read_csv('diabetes.csv')
raw_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
raw_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
raw_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
raw_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.pairplot(raw_data,hue='Outcome')

# %%
sns.distplot(raw_data['BMI'])

# %%
sns.distplot(raw_data['BloodPressure'],color='purple')

# %%
sns.distplot(raw_data['Glucose'],color='red')

# %%
sns.distplot(raw_data['DiabetesPedigreeFunction'],color='green')

# %%
sns.distplot(raw_data['SkinThickness'],color='orange')

# %%
new_df=raw_data.drop(raw_data[raw_data.Age<40].index)

# %%
new_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
new_df.Outcome.value_counts()
# Out:
# 1    108
# 0     99
# Name: Outcome, dtype: int64

# %%
sns.countplot(new_df['Outcome'])

# %%
x=new_df[['Age','BMI']]
y=new_df['Outcome']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([0.56301511, 0.29829992, 0.49493478, 0.69675765, 0.52063116,
#        0.39961452, 0.43411058, 0.56960579, 0.58271714, 0.89314707,
#        0.72136769, 0.42268189, 0.54983376, 0.63498711, 0.70117477,
#        0.30955316, 0.47656453, 0.75716097, 0.63064   , 0.68967609,
#        0.62590743, 0.42310278, 0.75337474, 0.61858042, 0.79221791,
#        0.61777409, 0.60354095, 0.71347979, 0.42061378, 0.4810871 ,
#        0.61118341, 0.52820361, 0.3848205 , 0.57532013, 0.54180586,
#        0.59807206, 0.53223529, 0.49255034, 0.49500478, 0.63884334,
#        0.53889596, 0.49924646, 0.41433855, 0.68855431, 0.51484681,
#        0.60515362, 0.47842265, 0.31390028, 0.43558325, 0.43442602,
#        0.55964977, 0.4597024 , 0.61777409, 0.61335697, 0.54748475,
#        0.55270821, 0.61503964, 0.63919423, 0.73199004, 0.38780039,
#        0.6464858 , 0.70061388, 0.33030697])

# %%
x_test.shape
# Out:
# (63, 2)

# %%
y_test.shape
# Out:
# (63,)

# %%
lr.predict([[55,35]])
# Out:
# array([0.52515372])
