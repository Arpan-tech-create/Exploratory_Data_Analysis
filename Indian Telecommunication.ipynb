# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
read=pd.read_csv('Indian telecommunications market.csv')

# %%
read
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10   11/2/2021 11:42:52                                 North
# 11   11/3/2021 15:36:07                                 North
# 12   11/7/2021 11:46:31                                  West
# 13   11/12/2021 9:04:52                                 North
# ...

# %%
read.head()
# Out:
#              Timestamp 1.Which region of India are you from?  \
# 0  10/28/2021 18:56:57                                  West
# 1  10/28/2021 19:14:06                                 North
# 2  10/28/2021 21:30:05                                  West
# 3  10/28/2021 23:06:31                                  East
# 4   10/29/2021 6:35:21                                  West
#
#   2.Which type of location do you live in?  \
# 0                                    Urban
# 1                                    Urban
# 2                                    Urban
# 3                                    Urban
# 4                                    Urban
#
#   3.Which tech are you currently using?  \
# 0                                    4G
# 1                                    4G
# 2                                    4G
# 3                                    4G
# 4                                    4G
#
# ...

# %%
read.info
# Out:
# <bound method DataFrame.info of               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10   11/2/2021 11:42:52                                 North
# 11   11/3/2021 15:36:07                                 North
# 12   11/7/2021 11:46:31                                  West
# 13   11/12/2021 9:04:52                                 North
# ...

# %%
read.describe
# Out:
# <bound method NDFrame.describe of               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10   11/2/2021 11:42:52                                 North
# 11   11/3/2021 15:36:07                                 North
# 12   11/7/2021 11:46:31                                  West
# 13   11/12/2021 9:04:52                                 North
# ...

# %%
read.shape
# Out:
# (50, 28)

# %%
read.tail()
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 45   11/23/2021 1:13:47                                  West
# 46  11/23/2021 14:50:27                                 South
# 47  11/23/2021 15:18:27                                 North
# 48  11/23/2021 17:33:13                                  West
# 49  11/23/2021 20:24:58                                  East
#
#    2.Which type of location do you live in?  \
# 45                                 Suburban
# 46                                    Urban
# 47                                    Urban
# 48                                 Suburban
# 49                                    Urban
#
#    3.Which tech are you currently using?  \
# 45                                    4G
# 46                                    4G
# 47                                    4G
# 48                                    4G
# 49                                    3G
#
# ...

# %%
var=['team1','winner','']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-eba897ee0cbe> in <module>
# ----> 1 sns.barplot(x='team1',y='winner',data=df.head(5))
#       2 plt.xlabel("teams")
#       3 plt.ylabel("winners")
#
# NameError: name 'df' is not defined
