# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_style('darkgrid')

plt.rcParams['font.size'] = 13
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
read1=pd.read_csv("IPL Matches 2008-2020.csv")
read1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
read1.drop(['neutral_venue'],axis=1,inplace=True)
read1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# ...

# %%
plt.figure(figsize=(15,8))
plt.title("Most Winning Team")
read1['winner'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
read1.shape
# Out:
# (816, 16)

# %%
read1.drop(['id'],axis=1,inplace=True)

# %%
read1
# Out:
#            city        date player_of_match  \
# 0     Bangalore  2008-04-18     BB McCullum
# 1    Chandigarh  2008-04-19      MEK Hussey
# 2         Delhi  2008-04-19     MF Maharoof
# 3        Mumbai  2008-04-20      MV Boucher
# 4       Kolkata  2008-04-20       DJ Hussey
# ..          ...         ...             ...
# 811       Dubai  2020-09-28  AB de Villiers
# 812       Dubai  2020-11-05       JJ Bumrah
# 813   Abu Dhabi  2020-11-06   KS Williamson
# 814   Abu Dhabi  2020-11-08      MP Stoinis
# 815       Dubai  2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# 3                              Wankhede Stadium               Mumbai Indians
# ...

# %%
read1.drop(['date'],axis=1,inplace=True)

# %%
read1
# Out:
#            city player_of_match                                       venue  \
# 0     Bangalore     BB McCullum                       M Chinnaswamy Stadium
# 1    Chandigarh      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2         Delhi     MF Maharoof                            Feroz Shah Kotla
# 3        Mumbai      MV Boucher                            Wankhede Stadium
# 4       Kolkata       DJ Hussey                                Eden Gardens
# ..          ...             ...                                         ...
# 811       Dubai  AB de Villiers         Dubai International Cricket Stadium
# 812       Dubai       JJ Bumrah         Dubai International Cricket Stadium
# 813   Abu Dhabi   KS Williamson                        Sheikh Zayed Stadium
# 814   Abu Dhabi      MP Stoinis                        Sheikh Zayed Stadium
# 815       Dubai        TA Boult         Dubai International Cricket Stadium
#
# ...

# %% [markdown]
# # removing null values from datasets

# %%
read1.isnull().sum()
# Out:
# city                13
# player_of_match      4
# venue                0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
read1.drop(read1[read1.city.isnull()].index, inplace=True)
read1.drop(read1[read1.player_of_match.isnull()].index, inplace=True)
read1.drop(read1[read1.method.isnull()].index, inplace=True)

# %%
read1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 40 to 667
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city             19 non-null     object
#  1   player_of_match  19 non-null     object
#  2   venue            19 non-null     object
#  3   team1            19 non-null     object
#  4   team2            19 non-null     object
#  5   toss_winner      19 non-null     object
#  6   toss_decision    19 non-null     object
#  7   winner           19 non-null     object
#  8   result           19 non-null     object
#  9   result_margin    19 non-null     float64
#  10  eliminator       19 non-null     object
#  11  method           19 non-null     object
#  12  umpire1          19 non-null     object
#  13  umpire2          19 non-null     object
# dtypes: float64(1), object(13)
# memory usage: 2.2+ KB

# %% [markdown]
# # Number Of Winning Matches Of Team

# %%
count=read1['winner'].value_counts()
count
# Out:
# Kolkata Knight Riders          4
# Royal Challengers Bangalore    3
# Kings XI Punjab                2
# Sunrisers Hyderabad            2
# Rising Pune Supergiants        2
# Chennai Super Kings            2
# Delhi Daredevils               2
# Rajasthan Royals               1
# Kochi Tuskers Kerala           1
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(20,7))
plt.xticks(rotation=70)
plt.title("Most Wins")
sns.barplot(x=count.index,y=count)

# %%
from IPython.display import Image
Image(filename='mi.jpg')

# %% [markdown]
# # Man Of The Match Player

# %%
man_match=read1.player_of_match.value_counts().head(15)
man_match
# Out:
# V Kohli             2
# AB Dinda            2
# CH Gayle            2
# M Ntini             1
# ML Hayden           1
# DA Warner           1
# SV Samson           1
# DW Steyn            1
# KL Rahul            1
# NM Coulter-Nile     1
# BB McCullum         1
# YK Pathan           1
# RR Pant             1
# DPMD Jayawardene    1
# Iqbal Abdulla       1
# Name: player_of_match, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=90)
plt.title("Popular Batsman")

sns.barplot(y=man_match.index,x=man_match)

# %%
from IPython.display import Image
Image(filename='ab.jpg')

# %%
read1.head(10)
# Out:
#               city   player_of_match  \
# 40           Delhi  DPMD Jayawardene
# 43         Kolkata           M Ntini
# 60       Cape Town        DL Vettori
# 63          Durban          CH Gayle
# 89       Centurion         ML Hayden
# 192          Kochi       BB McCullum
# 221        Kolkata     Iqbal Abdulla
# 231      Bangalore          CH Gayle
# 429          Delhi          DW Steyn
# 477  Visakhapatnam         DA Warner
#
#                                                  venue  \
# 40                                    Feroz Shah Kotla
# 43                                        Eden Gardens
# 60                                            Newlands
# 63                                           Kingsmead
# 89                                     SuperSport Park
# 192                                      Nehru Stadium
# 221                                       Eden Gardens
# 231                              M Chinnaswamy Stadium
# ...

# %%
new_df=['city','winner']
dataf=read1[new_df]

# %%
dataf
# Out:
#               city                       winner
# 40           Delhi              Kings XI Punjab
# 43         Kolkata          Chennai Super Kings
# 60       Cape Town             Delhi Daredevils
# 63          Durban        Kolkata Knight Riders
# 89       Centurion          Chennai Super Kings
# 192          Kochi         Kochi Tuskers Kerala
# 221        Kolkata        Kolkata Knight Riders
# 231      Bangalore  Royal Challengers Bangalore
# 429          Delhi          Sunrisers Hyderabad
# 477  Visakhapatnam          Sunrisers Hyderabad
# 508      Hyderabad  Royal Challengers Bangalore
# 538      Hyderabad      Rising Pune Supergiants
# 561        Kolkata        Kolkata Knight Riders
# 565  Visakhapatnam      Rising Pune Supergiants
# 566      Bangalore  Royal Challengers Bangalore
# 633      Bangalore        Kolkata Knight Riders
# 641         Jaipur             Rajasthan Royals
# 653        Kolkata              Kings XI Punjab
# 667          Delhi             Delhi Daredevils

# %%
dataf.head(4)
# Out:
#          city                 winner
# 40      Delhi        Kings XI Punjab
# 43    Kolkata    Chennai Super Kings
# 60  Cape Town       Delhi Daredevils
# 63     Durban  Kolkata Knight Riders

# %%
print(read1[['team1','city']].head(15))
# Out:
#                            team1           city
# 40              Delhi Daredevils          Delhi
# 43         Kolkata Knight Riders        Kolkata
# 60              Delhi Daredevils      Cape Town
# 63               Kings XI Punjab         Durban
# 89           Chennai Super Kings      Centurion
# 192         Kochi Tuskers Kerala          Kochi
# 221        Kolkata Knight Riders        Kolkata
# 231  Royal Challengers Bangalore      Bangalore
# 429             Delhi Daredevils          Delhi
# 477          Sunrisers Hyderabad  Visakhapatnam
# 508          Sunrisers Hyderabad      Hyderabad
# 538          Sunrisers Hyderabad      Hyderabad
# 561        Kolkata Knight Riders        Kolkata
# 565      Rising Pune Supergiants  Visakhapatnam
# 566  Royal Challengers Bangalore      Bangalore

# %%
print(read1.iloc[2])
# Out:
# city                      Cape Town
# player_of_match          DL Vettori
# venue                      Newlands
# team1              Delhi Daredevils
# team2               Kings XI Punjab
# toss_winner        Delhi Daredevils
# toss_decision                 field
# winner             Delhi Daredevils
# result                      wickets
# result_margin                    10
# eliminator                        N
# method                          D/L
# umpire1                   MR Benson
# umpire2                   SD Ranade
# Name: 60, dtype: object

# %%
read1.iloc[5]
# Out:
# city                              Kochi
# player_of_match             BB McCullum
# venue                     Nehru Stadium
# team1              Kochi Tuskers Kerala
# team2               Chennai Super Kings
# toss_winner        Kochi Tuskers Kerala
# toss_decision                     field
# winner             Kochi Tuskers Kerala
# result                          wickets
# result_margin                         7
# eliminator                            N
# method                              D/L
# umpire1                     K Hariharan
# umpire2                         AL Hill
# Name: 192, dtype: object

# %%
print(read1.iloc[1:6])
# Out:
#           city player_of_match            venue                  team1  \
# 43     Kolkata         M Ntini     Eden Gardens  Kolkata Knight Riders
# 60   Cape Town      DL Vettori         Newlands       Delhi Daredevils
# 63      Durban        CH Gayle        Kingsmead        Kings XI Punjab
# 89   Centurion       ML Hayden  SuperSport Park    Chennai Super Kings
# 192      Kochi     BB McCullum    Nehru Stadium   Kochi Tuskers Kerala
#
#                      team2            toss_winner toss_decision  \
# 43     Chennai Super Kings  Kolkata Knight Riders           bat
# 60         Kings XI Punjab       Delhi Daredevils         field
# 63   Kolkata Knight Riders  Kolkata Knight Riders         field
# 89         Kings XI Punjab    Chennai Super Kings           bat
# 192    Chennai Super Kings   Kochi Tuskers Kerala         field
#
#                     winner   result  result_margin eliminator method  \
# 43     Chennai Super Kings     runs            3.0          N    D/L
# ...

# %%
read1.columns
# Out:
# Index(['city', 'player_of_match', 'venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'winner', 'result', 'result_margin', 'eliminator',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
read1.describe()
# Out:
#        result_margin
# count      19.000000
# mean       14.000000
# std        17.885438
# min         3.000000
# 25%         6.500000
# 50%         9.000000
# 75%        11.500000
# max        82.000000

# %%
read1.head(3)
# Out:
#          city   player_of_match             venue                  team1  \
# 40      Delhi  DPMD Jayawardene  Feroz Shah Kotla       Delhi Daredevils
# 43    Kolkata           M Ntini      Eden Gardens  Kolkata Knight Riders
# 60  Cape Town        DL Vettori          Newlands       Delhi Daredevils
#
#                   team2            toss_winner toss_decision  \
# 40      Kings XI Punjab       Delhi Daredevils           bat
# 43  Chennai Super Kings  Kolkata Knight Riders           bat
# 60      Kings XI Punjab       Delhi Daredevils         field
#
#                  winner   result  result_margin eliminator method  \
# 40      Kings XI Punjab     runs            6.0          N    D/L
# 43  Chennai Super Kings     runs            3.0          N    D/L
# 60     Delhi Daredevils  wickets           10.0          N    D/L
#
#            umpire1      umpire2
# 40  AV Jayaprakash  RE Koertzen
# 43       Asad Rauf  K Hariharan
# 60       MR Benson    SD Ranade

# %%
read1.shape
# Out:
# (19, 14)

# %%
read1.tail()
# Out:
#           city  player_of_match                   venue  \
# 566  Bangalore          V Kohli   M Chinnaswamy Stadium
# 633  Bangalore  NM Coulter-Nile   M Chinnaswamy Stadium
# 641     Jaipur        SV Samson  Sawai Mansingh Stadium
# 653    Kolkata         KL Rahul            Eden Gardens
# 667      Delhi          RR Pant        Feroz Shah Kotla
#
#                            team1                  team2  \
# 566  Royal Challengers Bangalore        Kings XI Punjab
# 633          Sunrisers Hyderabad  Kolkata Knight Riders
# 641             Rajasthan Royals       Delhi Daredevils
# 653        Kolkata Knight Riders        Kings XI Punjab
# 667             Delhi Daredevils       Rajasthan Royals
#
#                toss_winner toss_decision                       winner  \
# 566        Kings XI Punjab         field  Royal Challengers Bangalore
# 633  Kolkata Knight Riders         field        Kolkata Knight Riders
# 641       Delhi Daredevils         field             Rajasthan Royals
# ...

# %%
read1['toss_winner'].value_counts()
# Out:
# Kolkata Knight Riders          4
# Rising Pune Supergiants        3
# Delhi Daredevils               3
# Sunrisers Hyderabad            2
# Kings XI Punjab                2
# Chennai Super Kings            2
# Rajasthan Royals               1
# Royal Challengers Bangalore    1
# Kochi Tuskers Kerala           1
# Name: toss_winner, dtype: int64

# %%
read1['venue'].value_counts()
# Out:
# Eden Gardens                                           4
# Feroz Shah Kotla                                       3
# M Chinnaswamy Stadium                                  3
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    2
# Rajiv Gandhi International Stadium, Uppal              2
# Sawai Mansingh Stadium                                 1
# SuperSport Park                                        1
# Newlands                                               1
# Nehru Stadium                                          1
# Kingsmead                                              1
# Name: venue, dtype: int64

# %%
read1['player_of_match'].value_counts().head(10).keys()
# Out:
# Index(['V Kohli', 'AB Dinda', 'CH Gayle', 'M Ntini', 'ML Hayden', 'DA Warner',
#        'SV Samson', 'DW Steyn', 'KL Rahul', 'NM Coulter-Nile'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.size'] = 12
plt.figure(figsize=(15,5))
sns.barplot(x="team1",y="result_margin",data=read1.sort_values(["toss_winner","toss_decision"]).head(10))
plt.xticks(rotation=40)
plt.xlabel("TEAMS")
plt.ylabel("WINS")
plt.title("Data Visualisation")
# Out:
# Text(0.5, 1.0, 'Data Visualisation')

# %%
read1['result'].value_counts()
# Out:
# runs       11
# wickets     8
# Name: result, dtype: int64

# %%
toss_win=read1.toss_winner.value_counts()
toss_win
# Out:
# Kolkata Knight Riders          4
# Rising Pune Supergiants        3
# Delhi Daredevils               3
# Sunrisers Hyderabad            2
# Kings XI Punjab                2
# Chennai Super Kings            2
# Rajasthan Royals               1
# Royal Challengers Bangalore    1
# Kochi Tuskers Kerala           1
# Name: toss_winner, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.title("MOST Toss Winning Team")
plt.xticks(rotation=70)
sns.barplot(x=toss_win.index,y=toss_win, palette="Blues_d")

# %%
new=['team1','team2','toss_winner','result','result_margin','winner']
new_df=read1[new]
new_df
# Out:
#                            team1                        team2  \
# 40              Delhi Daredevils              Kings XI Punjab
# 43         Kolkata Knight Riders          Chennai Super Kings
# 60              Delhi Daredevils              Kings XI Punjab
# 63               Kings XI Punjab        Kolkata Knight Riders
# 89           Chennai Super Kings              Kings XI Punjab
# 192         Kochi Tuskers Kerala          Chennai Super Kings
# 221        Kolkata Knight Riders          Chennai Super Kings
# 231  Royal Challengers Bangalore        Kolkata Knight Riders
# 429             Delhi Daredevils          Sunrisers Hyderabad
# 477          Sunrisers Hyderabad        Kolkata Knight Riders
# 508          Sunrisers Hyderabad  Royal Challengers Bangalore
# 538          Sunrisers Hyderabad      Rising Pune Supergiants
# 561        Kolkata Knight Riders      Rising Pune Supergiants
# 565      Rising Pune Supergiants             Delhi Daredevils
# ...

# %%
new_df.sort_values(by=['toss_winner'],ascending=False).head(5)
# Out:
#                            team1                        team2  \
# 508          Sunrisers Hyderabad  Royal Challengers Bangalore
# 429             Delhi Daredevils          Sunrisers Hyderabad
# 231  Royal Challengers Bangalore        Kolkata Knight Riders
# 565      Rising Pune Supergiants             Delhi Daredevils
# 561        Kolkata Knight Riders      Rising Pune Supergiants
#
#                      toss_winner   result  result_margin  \
# 508          Sunrisers Hyderabad  wickets            6.0
# 429          Sunrisers Hyderabad  wickets            8.0
# 231  Royal Challengers Bangalore  wickets            4.0
# 565      Rising Pune Supergiants     runs           19.0
# 561      Rising Pune Supergiants  wickets            8.0
#
#                           winner
# 508  Royal Challengers Bangalore
# 429          Sunrisers Hyderabad
# 231  Royal Challengers Bangalore
# 565      Rising Pune Supergiants
# 561        Kolkata Knight Riders

# %%
read1['result_margin'].max()
# Out:
# 82.0

# %%
var=['team1','city','winner']
df=read1[var]
df
# Out:
#                            team1           city                       winner
# 40              Delhi Daredevils          Delhi              Kings XI Punjab
# 43         Kolkata Knight Riders        Kolkata          Chennai Super Kings
# 60              Delhi Daredevils      Cape Town             Delhi Daredevils
# 63               Kings XI Punjab         Durban        Kolkata Knight Riders
# 89           Chennai Super Kings      Centurion          Chennai Super Kings
# 192         Kochi Tuskers Kerala          Kochi         Kochi Tuskers Kerala
# 221        Kolkata Knight Riders        Kolkata        Kolkata Knight Riders
# 231  Royal Challengers Bangalore      Bangalore  Royal Challengers Bangalore
# 429             Delhi Daredevils          Delhi          Sunrisers Hyderabad
# 477          Sunrisers Hyderabad  Visakhapatnam          Sunrisers Hyderabad
# 508          Sunrisers Hyderabad      Hyderabad  Royal Challengers Bangalore
# ...

# %%
df['team1'].value_counts()
# Out:
# Sunrisers Hyderabad            4
# Kolkata Knight Riders          4
# Delhi Daredevils               4
# Royal Challengers Bangalore    2
# Rajasthan Royals               1
# Kochi Tuskers Kerala           1
# Kings XI Punjab                1
# Rising Pune Supergiants        1
# Chennai Super Kings            1
# Name: team1, dtype: int64

# %%
slot_one=read1.team1.value_counts()
slot_one
# Out:
# Sunrisers Hyderabad            4
# Kolkata Knight Riders          4
# Delhi Daredevils               4
# Royal Challengers Bangalore    2
# Rajasthan Royals               1
# Kochi Tuskers Kerala           1
# Kings XI Punjab                1
# Rising Pune Supergiants        1
# Chennai Super Kings            1
# Name: team1, dtype: int64

# %%
plt.figure(figsize=(15,7))
plt.title("TEAM-1 SLOT")
sns.barplot(y=slot_one.index,x=slot_one,color='red')

# %% [markdown]
# # Royal Challengers Bangalore

# %%
from IPython.display import Image
Image(filename='rcb.jpg')

# %% [markdown]
# # Which one is the most Favourite Venue For IPL?

# %%
popular_ven=read1.venue.value_counts()

# %%
popular_ven
# Out:
# Eden Gardens                                           4
# Feroz Shah Kotla                                       3
# M Chinnaswamy Stadium                                  3
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    2
# Rajiv Gandhi International Stadium, Uppal              2
# Sawai Mansingh Stadium                                 1
# SuperSport Park                                        1
# Newlands                                               1
# Nehru Stadium                                          1
# Kingsmead                                              1
# Name: venue, dtype: int64

# %%
plt.figure(figsize=(15,7))
plt.title("Hot Favourite Venue",color='red',size=16)
plt.xticks(rotation=90)
sns.barplot(x=popular_ven.index,y=popular_ven,color='green')

# %% [markdown]
# # EDEN GARDEN - KOLKATA

# %%
from IPython.display import Image
Image(filename='eden-garden.jpg')

# %%
read1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # Toss : BAT FIRST , Most WINNING TEAM=CSK

# %%
bat_first=read1.winner[read1.toss_decision=='bat']
bat_first.value_counts()
# Out:
# Chennai Super Kings            55
# Mumbai Indians                 50
# Kolkata Knight Riders          38
# Rajasthan Royals               37
# Royal Challengers Bangalore    31
# Delhi Daredevils               29
# Kings XI Punjab                24
# Sunrisers Hyderabad            23
# Deccan Chargers                14
# Pune Warriors                   9
# Delhi Capitals                  5
# Gujarat Lions                   2
# Rising Pune Supergiants         2
# Name: winner, dtype: int64

# %% [markdown]
# # TOSS : BOWL FIRST ,  Most winning team : MI

# %%
bowl_first=read1.winner[read1.toss_decision=='field']
bowl_first.value_counts()
# Out:
# Mumbai Indians                 70
# Kings XI Punjab                64
# Kolkata Knight Riders          61
# Royal Challengers Bangalore    60
# Chennai Super Kings            51
# Rajasthan Royals               44
# Sunrisers Hyderabad            43
# Delhi Daredevils               38
# Deccan Chargers                15
# Delhi Capitals                 14
# Gujarat Lions                  11
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         3
# Pune Warriors                   3
# Name: winner, dtype: int64

# %%
num=read1[['winner','result_margin']]
csk=read1.winner=='Chennai Super Kings'

# %%
csk_df=num[csk]
top_team=csk_df.sort_values(by=['result_margin'],ascending=False).head(10)
top_team
# Out:
#                  winner  result_margin
# 89  Chennai Super Kings           12.0
# 43  Chennai Super Kings            3.0

# %%
new_team=read1[['winner','result_margin']]
mi=read1.winner=='Mumbai Indians'

# %%
mi_df=new_team[mi]
mi_team=mi_df.sort_values(by=['result_margin'],ascending=False).head(10)
mi_team
# Out:
# Empty DataFrame
# Columns: [winner, result_margin]
# Index: []

# %%
# !pip install wordcloud --quiet
from wordcloud import WordCloud

# %%
comment_words = ' '
  
for val in read1.winner.values: 
    val = str(val) 
    tokens = val.split() 
        
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 1000, height = 1000, 
                background_color ='white', 
                min_font_size = 10).generate(comment_words) 
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x1930C165D90>
