# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams['figure.figsize']=(15,7)
plt.rcParams['font.size']=15
sns.set_style('darkgrid')

# %%
read=pd.read_csv('Flipkart Mobile - 2.csv')

# %%
read
# Out:
#       brand           model base_color processor screen_size  ROM  RAM  \
# 0     Apple       iPhone SE      Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE        Red     Water  Very Small   64    2
# 3     Apple       iPhone XR     Others       iOS      Medium   64    3
# 4     Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..      ...             ...        ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# ...

# %%
read.describe()
# Out:
#               ROM         RAM  display_size  num_rear_camera  \
# count  430.000000  430.000000    430.000000       430.000000
# mean   105.748837    5.320930      6.369767         2.904651
# std     63.164064    2.182635      0.369549         0.952350
# min      8.000000    1.000000      4.700000         1.000000
# 25%     64.000000    4.000000      6.300000         2.000000
# 50%    128.000000    4.000000      6.500000         3.000000
# 75%    128.000000    6.000000      6.500000         4.000000
# max    512.000000   12.000000      7.600000         4.000000
#
#        num_front_camera  battery_capacity     ratings  num_of_ratings  \
# count        430.000000        430.000000  430.000000      430.000000
# mean           1.044186       4529.397674    4.339302    23567.944186
# std            0.227280        986.907252    0.151494    56096.277784
# min            1.000000       1800.000000    3.000000        4.000000
# ...

# %%
print(read['sales_price'].quantile(.90))
print(read['sales_price'].quantile(.10))
# Out:
# 57149.0
# 8999.0

# %%
read.plot(kind='scatter',x='num_of_ratings',y='sales_price',alpha=0.1)

# %%
name=read.brand
rat=read.sales_price
sal=read.num_of_ratings

# %%
plt.figure(figsize=(15,6))
plt.plot(name,rat)
plt.plot(name,sal)
plt.legend(['Ratings','Sales'])

# %% [markdown]
# # i have to findout that, which brand has done max sales ?

# %%
new_sales=read.brand[read.sales>50]
new_sales.value_counts()
# Out:
# Realme     22
# Xiaomi     19
# Poco       15
# Samsung     8
# Apple       4
# Name: brand, dtype: int64

# %%
from IPython.display import Image
Image(filename='RealMe.jpg')

# %% [markdown]
# so, Yes  it's Realme

# %%
model_df=read.model[read.discount_percent.value_counts()]
model_df.value_counts()
# Out:
# iPhone 12         12
# iPhone XR         11
# iPhone 12 Mini     8
# iPhone SE          2
# Name: model, dtype: int64

# %%
read.isnull().sum()
# Out:
# brand               0
# model               0
# base_color          0
# processor           0
# screen_size         0
# ROM                 0
# RAM                 0
# display_size        0
# num_rear_camera     0
# num_front_camera    0
# battery_capacity    0
# ratings             0
# num_of_ratings      0
# sales_price         0
# discount_percent    0
# sales               0
# dtype: int64

# %%
read.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# 0           4.7                1                 1              1800      4.5
# 1           5.4                2                 1              2815      4.5
# 2           4.7                1                 1              1800      4.5
# 3           6.1                1                 1              2942      4.6
# 4           6.1                2                 1              2815      4.6
#
#    num_of_ratings  sales_price  discount_percent   sales
# ...

# %%
read.tail(3)
# Out:
#       brand          model base_color processor screen_size  ROM  RAM  \
# 427  Xiaomi     Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi  Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi    Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# 427           6.5                3                 1              4250
# 428           6.2                2                 1              5000
# 429           5.8                2                 1              4000
#
#      ratings  num_of_ratings  sales_price  discount_percent  sales
# 427      4.2            1554        21999              0.12   3.42
# 428      4.2            8161         8299              0.07   6.77
# 429      4.3            1870         8190              0.36   1.53

# %% [markdown]
# # Which Brand Has Maximum Sales-Price?

# %%
max_sales=read.brand[read.sales_price.value_counts()]
max_sales.value_counts()
# Out:
# Apple    141
# Name: brand, dtype: int64

# %%
from IPython.display import Image
Image(filename='Apple-Logo.jpg')

# %%
plt.figure(figsize = (15,6))
sns.boxplot(x = 'brand',y = 'sales_price',data = read)
plt.title("Brand's Total Sales Price")
plt.show()

# %% [markdown]
# # Which Brand Has maximum number of ratings?

# %%
new_ratings=read.brand[read.num_of_ratings.value_counts()]
new_ratings.value_counts()
# Out:
# Apple    175
# Name: brand, dtype: int64

# %%
#count plots
plt.figure(figsize = (15,6))
sns.countplot(read['brand'], palette = 'rocket',edgecolor='lightgreen')
plt.title("Brand")
plt.xticks(rotation=60)
plt.show()

# %%
#base color counts
plt.figure(figsize = (15,6))
sns.countplot(read['base_color'], palette = 'magma')
plt.title("Brand")
plt.xticks(rotation=60)
plt.show()

# %%
my_brand = read.groupby(['brand', 'base_color','battery_capacity']).size().reset_index(name = 'Count')
my_brand
# Out:
#       brand base_color  battery_capacity  Count
# 0     Apple      Black              1800      2
# 1     Apple      Black              2815      6
# 2     Apple      Black              2942      4
# 3     Apple       Blue              2815      5
# 4     Apple       Blue              2942      3
# ..      ...        ...               ...    ...
# 131  Xiaomi      White              4000      3
# 132  Xiaomi      White              4030      1
# 133  Xiaomi      White              4520      1
# 134  Xiaomi      White              5000      1
# 135  Xiaomi      White              5020      1
#
# [136 rows x 4 columns]

# %%
my_df = read.groupby(['brand', 'base_color','RAM','ROM']).size().reset_index(name = 'Count')
my_df
# Out:
#       brand base_color  RAM  ROM  Count
# 0     Apple      Black    2   32      1
# 1     Apple      Black    2   64      1
# 2     Apple      Black    3   64      2
# 3     Apple      Black    3  128      2
# 4     Apple      Black    4   64      2
# ..      ...        ...  ...  ...    ...
# 192  Xiaomi     Silver    6  128      2
# 193  Xiaomi      White    3   32      1
# 194  Xiaomi      White    4   64      2
# 195  Xiaomi      White    6   64      1
# 196  Xiaomi      White    6  128      3
#
# [197 rows x 5 columns]

# %%
plt.figure(figsize=(14,6))
plt.xticks(rotation=60)
sns.barplot(x='brand',y='Count',data=my_brand,hue='brand',palette = 'rocket')
plt.title('Brand-Color')
plt.legend(bbox_to_anchor = (1.04,1), borderaxespad = 0)
plt.show()

# %%
brand_df = read.groupby(['brand','model', 'base_color','RAM']).size().reset_index(name = 'Count')
brand_df
# Out:
#       brand             model base_color  RAM  Count
# 0     Apple         iPhone 12      Black    4      3
# 1     Apple         iPhone 12       Blue    4      3
# 2     Apple         iPhone 12      Green    4      3
# 3     Apple         iPhone 12     Purple    4      2
# 4     Apple         iPhone 12        Red    4      3
# ..      ...               ...        ...  ...    ...
# 353  Xiaomi  Redmi Note 9 Pro      White    4      1
# 354  Xiaomi          Redmi Y2       Gold    3      1
# 355  Xiaomi          Redmi Y3      Black    4      1
# 356  Xiaomi          Redmi Y3        Red    3      1
# 357  Xiaomi          Redmi Y3        Red    4      1
#
# [358 rows x 5 columns]

# %%
x=read["brand"]
y=read["ratings"]
plt.figure(figsize=(15,5))
plt.xticks(rotation=60)
plt.xlabel("Brands",fontsize=14)
plt.ylabel("Total_Ratings",fontsize=14)
sns.barplot(x,y)

# %%
mb=read[['brand','model','num_of_ratings']]
app=read.brand=='Apple'

# %%
app_df=mb[app]
app_brand1=app_df.sort_values(by=['num_of_ratings'],ascending=False)
app_brand1
# Out:
#     brand           model  num_of_ratings
# 0   Apple       iPhone SE           38645
# 2   Apple       iPhone SE           38645
# 35  Apple       iPhone SE           38645
# 43  Apple   iPhone 7 Plus           29713
# 42  Apple        iPhone 8           11281
# 44  Apple       iPhone XR            5366
# 24  Apple       iPhone XR            5366
# 27  Apple       iPhone XR            5366
# 29  Apple       iPhone XR            5366
# 21  Apple       iPhone XR            5366
# 33  Apple       iPhone XR            5366
# 15  Apple       iPhone XR            5366
# 45  Apple       iPhone XR            5366
# 46  Apple       iPhone XR            5366
# 47  Apple       iPhone XR            5366
# 48  Apple       iPhone XR            5366
# 49  Apple       iPhone XR            5366
# 50  Apple       iPhone XR            5366
# 51  Apple       iPhone XR            5366
# 53  Apple       iPhone XR            5366
# 54  Apple       iPhone XR            5366
# ...

# %%
app_brand1.head()
# Out:
#     brand          model  num_of_ratings
# 0   Apple      iPhone SE           38645
# 2   Apple      iPhone SE           38645
# 35  Apple      iPhone SE           38645
# 43  Apple  iPhone 7 Plus           29713
# 42  Apple       iPhone 8           11281

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='model',y='num_of_ratings',data=app_brand1)

# %%
mb1=read[['brand','model','num_of_ratings']]
xi=read.brand=='Xiaomi'

# %%
xi_df=mb1[xi]
xi_brand1=xi_df.sort_values(by=['num_of_ratings'],ascending=False)
xi_brand1
# Out:
#       brand             model  num_of_ratings
# 395  Xiaomi      Redmi Note 4          642373
# 418  Xiaomi             Mi A1          470905
# 396  Xiaomi      Redmi Note 5          357064
# 402  Xiaomi  Redmi Note 7 Pro          141177
# 412  Xiaomi  Redmi Note 7 Pro          141177
# ..      ...               ...             ...
# 403  Xiaomi  Redmi Note 9 Pro             434
# 408  Xiaomi             Mi 10             283
# 377  Xiaomi            Mi 11X             194
# 370  Xiaomi            Mi 11X             194
# 417  Xiaomi     Mi 11X Pro 5G              35
#
# [61 rows x 3 columns]

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=70)
sns.barplot(y='model',x='num_of_ratings',data=xi_brand1.head(25))

# %% [markdown]
# # About POCO Brand

# %%
mb1=read[['brand','model','num_of_ratings']]
poco=read.brand=='Poco'

# %%
poco_df=mb1[poco]
poco_brand1=poco_df.sort_values(by=['num_of_ratings'],ascending=False)
poco_brand1
# Out:
#     brand        model  num_of_ratings
# 110  Poco           X2          267028
# 98   Poco           F1          122001
# 111  Poco           M2           98156
# 108  Poco           M2           98156
# 107  Poco           M2           98156
# 102  Poco           M2           98156
# 59   Poco           C3           54470
# 61   Poco           C3           54470
# 69   Poco           C3           54470
# 67   Poco           M3           39881
# 99   Poco           M3           39881
# 84   Poco           M3           39881
# 64   Poco           M3           39881
# 60   Poco           M3           39881
# 62   Poco           M3           39881
# 68   Poco           C3           38496
# 56   Poco           C3           38496
# 70   Poco           C3           38496
# 82   Poco       M2 Pro           33364
# 81   Poco       M2 Pro           33364
# 87   Poco       M2 Pro           33364
# 101  Poco       M2 Pro           33364
# 100  Poco       M2 Pro           33364
# ...

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=70)

poco=sns.barplot(x='model',y='num_of_ratings',data=poco_brand1)

# %% [markdown]
# # POCO X2

# %%
from IPython.display import Image
Image(filename='poco.jpg')

# %%
pr=read.processor.value_counts()
pr
# Out:
# Qualcomm    168
# MediaTek    144
# Exynos       53
# Ceramic      33
# iOS          12
# Water        11
# Others        9
# Name: processor, dtype: int64

# %% [markdown]
# # Which One Is The Most Popular Processor ?

# %%
import math

def roundup(x):
    return 100 + int(math.ceil(x / 100.0)) * 100 

sns.factorplot('processor',data=read, kind='count', size=14, aspect=1,palette='Blues_d')
ax = plt.gca()
y_max = read['processor'].value_counts().max() 
ax.set_ylim([0, roundup(y_max)])
plt.xticks(rotation=60)
# Iterate through the list of axes' patches
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
            fontsize=14, color='blue', ha='center', va='bottom')

plt.show()
# Out:
# C:\Users\ARPAN\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\ARPAN\anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from IPython.display import Image
Image(filename='qualcomm-snapdragon.jpg')

# %%
sam=read[['model','base_color','sales','RAM']]
sam_df=read.model=='Galaxy F41'

# %%
mob=sam[sam_df]
mob_df=mob.sort_values(by=['sales'],ascending=False).head(50)
mob_df
# Out:
#           model base_color  sales  RAM
# 291  Galaxy F41      Green  98.89    6
# 345  Galaxy F41      Black  98.89    6
# 346  Galaxy F41       Blue  98.89    6
# 341  Galaxy F41      Green  89.62    6
# 342  Galaxy F41      Black  89.62    6
# 343  Galaxy F41       Blue  89.62    6

# %%
mobi=mob_df.base_color[mob_df.model=='Galaxy F41']
mobi.value_counts()
# Out:
# Black    2
# Blue     2
# Green    2
# Name: base_color, dtype: int64

# %%
read.model.value_counts()
# Out:
# iPhone XR            18
# iPhone 12            17
# iPhone 12 Mini       16
# GT Master Edition     9
# M3                    9
#                      ..
# Galaxy A10            1
# Galaxy J6             1
# Redmi 5               1
# Galaxy M11            1
# Galaxy M30s           1
# Name: model, Length: 119, dtype: int64

# %%
read.battery_capacity.value_counts()
# Out:
# 5000    129
# 6000     54
# 4000     49
# 4500     42
# 2815     33
# 2942     18
# 4300     16
# 4200      9
# 3300      8
# 4035      6
# 5160      6
# 4230      6
# 4250      6
# 5065      6
# 7000      6
# 1800      5
# 4310      4
# 5020      4
# 4400      3
# 4520      3
# 4030      3
# 3400      2
# 4820      2
# 3000      2
# 2600      2
# 3080      2
# 4800      1
# 4780      1
# 3700      1
# 4100      1
# Name: battery_capacity, dtype: int64

# %%
bat=read[['model','num_of_ratings','sales_price','battery_capacity']]
bat_df=read.battery_capacity==5000

# %%
new=bat_df[bat]
new_bat1=new.sort_values(by=['sales_price'],ascending=False,inplace=True)
new_bat1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-1eda1c07c800> in <module>
# ----> 1 new=bat_df[bat]
#       2 new_bat1=new.sort_values(by=['sales_price'],ascending=False,inplace=True)
#       3 new_bat1
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     908             key = check_bool_indexer(self.index, key)
#     909
# --> 910         return self._get_with(key)
#     911
#     912     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     915             return self._slice(key)
#     916         elif isinstance(key, ABCDataFrame):
# --> 917             raise TypeError(
#     918                 "Indexing a Series with DataFrame is not "
#     919                 "supported, use the appropriate DataFrame column"
#
# ...

# %%
# !pip install wordcloud --quiet
from wordcloud import WordCloud

# %%
comment_words = ' '
  
for val in read.model.values: 
    val = str(val) 
    tokens = val.split() 
        
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 1000, height = 1000, 
                background_color ='black', 
                min_font_size = 10).generate(comment_words) 
wordcloud.to_image()
